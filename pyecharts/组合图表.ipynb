# %% [markdown]
# # Grid：并行多图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line, Scatter


def grid_vertical() -> Grid:
    bar = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Grid-Bar"))
    )
    line = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Grid-Line", pos_top="48%"),
            legend_opts=opts.LegendOpts(pos_top="48%"),
        )
    )
    
    overlap = bar.overlap(line)

    grid = (
        Grid()
        .add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))
        .add(line, grid_opts=opts.GridOpts(pos_top="60%"))
#         .add(overlap, grid_opts=opts.GridOpts(pos_top="60%"))
    )
    
    return grid
grid = grid_vertical()
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cc17518e7cd54b22bd75755389940796" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cc17518e7cd54b22bd75755389940796 = echarts.init(
#                     document.getElementById('cc17518e7cd54b22bd75755389940796'), 'white', {renderer: 'canvas'});
#                 var option_cc17518e7cd54b22bd75755389940796 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 27,
#                 65,
#                 122,
#                 97,
#                 97,
#                 88,
#                 68
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 92,
#                 74,
#                 86,
#                 71,
#                 131,
#                 55,
#                 110
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     62
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     78
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     110
#                 ],
#                 [
#                     "\u5468\u56db",
#                     101
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     98
#                 ],
#                 [
#                     "\u5468\u516d",
#                     98
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     122
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     120
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     89
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     120
#                 ],
#                 [
#                     "\u5468\u56db",
#                     71
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     68
#                 ],
#                 [
#                     "\u5468\u516d",
#                     72
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     53
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     62
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     78
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     110
#                 ],
#                 [
#                     "\u5468\u56db",
#                     101
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     98
#                 ],
#                 [
#                     "\u5468\u516d",
#                     98
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     122
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     120
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     89
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     120
#                 ],
#                 [
#                     "\u5468\u56db",
#                     71
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     68
#                 ],
#                 [
#                     "\u5468\u516d",
#                     72
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     53
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",

# %%
def grid_horizontal() -> Grid:
    scatter = (
        Scatter()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Grid-Scatter"),
            legend_opts=opts.LegendOpts(pos_left="20%"),
        )
    )
    line = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Grid-Line", pos_right="5%"),
            legend_opts=opts.LegendOpts(pos_right="20%"),
        )
    )
    line2 = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Grid-Line", pos_right="5%"),
            legend_opts=opts.LegendOpts(pos_right="20%"),
        )
    )
    overlap = line2.overlap(scatter)

    grid = (
        Grid()
        .add(overlap, grid_opts=opts.GridOpts(pos_top="55%"))
        .add(scatter, grid_opts=opts.GridOpts(pos_bottom='55%', pos_left="55%"))
        .add(line, grid_opts=opts.GridOpts(pos_bottom='55%', pos_right="55%"))
         
    )
    return grid
grid = grid_horizontal()
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0a817848d9b846c88005a47c06225b62" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0a817848d9b846c88005a47c06225b62 = echarts.init(
#                     document.getElementById('0a817848d9b846c88005a47c06225b62'), 'white', {renderer: 'canvas'});
#                 var option_0a817848d9b846c88005a47c06225b62 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     149
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     38
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     147
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     72
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     39
#                 ],
#                 [
#                     "VIVO",
#                     148
#                 ],
#                 [
#                     "OPPO",
#                     130
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     135
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     90
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     66
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     50
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     108
#                 ],
#                 [
#                     "VIVO",
#                     39
#                 ],
#                 [
#                     "OPPO",
#                     30
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     57
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     106
#                 ],
#                 [
#                     "\u8001\u864e",
#                     141
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     81
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     99
#                 ],
#                 [
#                     "\u718a\u732b",
#                     26
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     47
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     145
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     148
#                 ],
#                 [
#                     "\u8001\u864e",
#                     74
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     87
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     128
#                 ],
#                 [
#                     "\u718a\u732b",
#                     39
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     51
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     57
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     106
#                 ],
#                 [
#                     "\u8001\u864e",
#                     141
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     81
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     99
#                 ],
#                 [
#                     "\u718a\u732b",
#                     26
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     47
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     145
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     148
#                 ],
#                 [
#                     "\u8001\u864e",
#                     74
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     87
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     128
#                 ],
#                 [
#                     "\u718a\u732b",
#                     39
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     51

# %%
def grid_mutil_yaxis() -> Grid:
    x_data = ["{}月".format(i) for i in range(1, 13)]
    bar = (
        Bar()
        .add_xaxis(x_data)
        .add_yaxis(
            "蒸发量",
            [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3],
            yaxis_index=0,
            color="#d14a61",
        )
        .add_yaxis(
            "降水量",
            [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3],
            yaxis_index=1,
            color="#5793f3",
        )
        .extend_axis(
            yaxis=opts.AxisOpts(
                name="蒸发量",
                type_="value",
                min_=0,
                max_=250,
                position="right",
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#d14a61")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
            )
        )
        .extend_axis(
            yaxis=opts.AxisOpts(
                type_="value",
                name="温度",
                min_=0,
                max_=25,
                position="left",
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#675bba")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
                splitline_opts=opts.SplitLineOpts(
                    is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
                ),
            )
        )
        .set_global_opts(
            yaxis_opts=opts.AxisOpts(
                name="降水量",
                min_=0,
                max_=250,
                position="right",
                offset=80,
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#5793f3")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
            ),
            title_opts=opts.TitleOpts(title="Grid-多 Y 轴示例"),
            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        )
    )

    line = (
        Line()
        .add_xaxis(x_data)
        .add_yaxis(
            "平均温度",
            [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2],
            yaxis_index=2,
            color="#675bba",
            label_opts=opts.LabelOpts(is_show=False),
        )
    )

    bar.overlap(line)
    return Grid().add(bar, opts.GridOpts(pos_left="5%", pos_right="30%"), is_control_axis_index=True)
#     return bar
grid = grid_mutil_yaxis()
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="af6dd4bfa1f54630820075753754a385" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_af6dd4bfa1f54630820075753754a385 = echarts.init(
#                     document.getElementById('af6dd4bfa1f54630820075753754a385'), 'white', {renderer: 'canvas'});
#                 var option_af6dd4bfa1f54630820075753754a385 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#5793f3",
#         "#d14a61",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "yAxisIndex": 0,
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "yAxisIndex": 1,
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u6e29\u5ea6",
#             "connectNulls": false,
#             "yAxisIndex": 2,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1\u6708",
#                     2.0
#                 ],
#                 [
#                     "2\u6708",
#                     2.2
#                 ],
#                 [
#                     "3\u6708",
#                     3.3
#                 ],
#                 [
#                     "4\u6708",
#                     4.5
#                 ],
#                 [
#                     "5\u6708",
#                     6.3
#                 ],
#                 [
#                     "6\u6708",
#                     10.2
#                 ],
#                 [
#                     "7\u6708",
#                     20.3
#                 ],
#                 [
#                     "8\u6708",
#                     23.4
#                 ],
#                 [
#                     "9\u6708",
#                     23.0
#                 ],
#                 [
#                     "10\u6708",
#                     16.5
#                 ],
#                 [
#                     "11\u6708",
#                     12.0
#                 ],
#                 [
#                     "12\u6708",
#                     6.2
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u84b8\u53d1\u91cf",
#                 "\u964d\u6c34\u91cf",
#                 "\u5e73\u5747\u6e29\u5ea6"
#             ],
#             "selected": {
#                 "\u84b8\u53d1\u91cf": true,
#                 "\u964d\u6c34\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708",
#                 "8\u6708",
#                 "9\u6708",
#                 "10\u6708",
#                 "11\u6708",
#                 "12\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u964d\u6c34\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#5793f3"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} ml"
#             },
#             "inverse": false,
#             "position": "right",
#             "offset": 80,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 250,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "\u84b8\u53d1\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#d14a61"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} ml"
#             },
#             "inverse": false,
#             "position": "right",
#             "offset": 0,
#             "splitNumber": 5,

# %%
from pyecharts.charts import Kline
def kline_profession_example() -> Grid:

    data = [
        [2320.26, 2320.26, 2287.3, 2362.94],
        [2300, 2291.3, 2288.26, 2308.38],
        [2295.35, 2346.5, 2295.35, 2345.92],
        [2347.22, 2358.98, 2337.35, 2363.8],
        [2360.75, 2382.48, 2347.89, 2383.76],
        [2383.43, 2385.42, 2371.23, 2391.82],
        [2377.41, 2419.02, 2369.57, 2421.15],
        [2425.92, 2428.15, 2417.58, 2440.38],
        [2411, 2433.13, 2403.3, 2437.42],
        [2432.68, 2334.48, 2427.7, 2441.73],
        [2430.69, 2418.53, 2394.22, 2433.89],
        [2416.62, 2432.4, 2414.4, 2443.03],
        [2441.91, 2421.56, 2418.43, 2444.8],
        [2420.26, 2382.91, 2373.53, 2427.07],
        [2383.49, 2397.18, 2370.61, 2397.94],
        [2378.82, 2325.95, 2309.17, 2378.82],
        [2322.94, 2314.16, 2308.76, 2330.88],
        [2320.62, 2325.82, 2315.01, 2338.78],
        [2313.74, 2293.34, 2289.89, 2340.71],
        [2297.77, 2313.22, 2292.03, 2324.63],
        [2322.32, 2365.59, 2308.92, 2366.16],
        [2364.54, 2359.51, 2330.86, 2369.65],
        [2332.08, 2273.4, 2259.25, 2333.54],
        [2274.81, 2326.31, 2270.1, 2328.14],
        [2333.61, 2347.18, 2321.6, 2351.44],
        [2340.44, 2324.29, 2304.27, 2352.02],
        [2326.42, 2318.61, 2314.59, 2333.67],
        [2314.68, 2310.59, 2296.58, 2320.96],
        [2309.16, 2286.6, 2264.83, 2333.29],
        [2282.17, 2263.97, 2253.25, 2286.33],
        [2255.77, 2270.28, 2253.31, 2276.22],
    ]

    def calculate_ma(day_count: int, d):
        result: List[Union[float, str]] = []
        for i in range(len(d)):
            if i < day_count:
                result.append("-")
                continue
            sum_total = 0.0
            for j in range(day_count):
                sum_total += float(d[i - j][1])
            result.append(abs(float("%.3f" % (sum_total / day_count))))
        return result

    x_data = ["2017-7-{}".format(i + 1) for i in range(31)]

    kline = (
        Kline()
        .add_xaxis(xaxis_data=x_data)
        .add_yaxis(
            series_name="Dow-Jones index",
            y_axis=data,
            itemstyle_opts=opts.ItemStyleOpts(color="#ec0000", color0="#00da3c"),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title="复杂版 Kline 示例 (Kline + Line + Bar)",
                subtitle="MA 就以(2, 4, 6, 8为例)",
            ),
            xaxis_opts=opts.AxisOpts(type_="category"),
            yaxis_opts=opts.AxisOpts(
                is_scale=True,
                splitarea_opts=opts.SplitAreaOpts(
                    is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
                ),
            ),
            legend_opts=opts.LegendOpts(
                is_show=False, pos_bottom=10, pos_left="center"
            ),
            datazoom_opts=[
                opts.DataZoomOpts(
                    is_show=False,
                    type_="inside",
                    xaxis_index=[0, 1],
                    range_start=0,
                    range_end=100,
                ),
                opts.DataZoomOpts(
                    is_show=True,
                    xaxis_index=[0, 1],
                    type_="slider",
                    pos_top="90%",
                    range_start=0,
                    range_end=100,
                ),
            ],
            tooltip_opts=opts.TooltipOpts(
                trigger="axis",
                axis_pointer_type="cross",
                background_color="rgba(245, 245, 245, 0.8)",
                border_width=1,
                border_color="#ccc",
                textstyle_opts=opts.TextStyleOpts(color="#000"),
            ),
            visualmap_opts=opts.VisualMapOpts(
                is_show=False,
                dimension=2,
                series_index=5,
                is_piecewise=True,
                pieces=[
                    {"value": 1, "color": "#ec0000"},
                    {"value": -1, "color": "#00da3c"},
                ],
            ),
            axispointer_opts=opts.AxisPointerOpts(
                is_show=True,
                link=[{"xAxisIndex": "all"}],
                label=opts.LabelOpts(background_color="#777"),
            ),
            brush_opts=opts.BrushOpts(
                x_axis_index="all",
                brush_link="all",
                out_of_brush={"colorAlpha": 0.1},
                brush_type="lineX",
            ),
        )
    )

    line = (
        Line()
        .add_xaxis(xaxis_data=x_data)
        .add_yaxis(
            series_name="MA2",
            y_axis=calculate_ma(day_count=2, d=data),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=3, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="MA4",
            y_axis=calculate_ma(day_count=4, d=data),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=3, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="MA6",
            y_axis=calculate_ma(day_count=6, d=data),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=3, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add_yaxis(
            series_name="MA8",
            y_axis=calculate_ma(day_count=8, d=data),
            is_smooth=True,
            is_hover_animation=False,
            linestyle_opts=opts.LineStyleOpts(width=3, opacity=0.5),
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(xaxis_opts=opts.AxisOpts(type_="category"))
    )

    bar = (
        Bar()
        .add_xaxis(xaxis_data=x_data)
        .add_yaxis(
            series_name="Volume",
            yaxis_data=[
                [i, data[i][3], 1 if data[i][0] > data[i][1] else -1]
                for i in range(len(data))
            ],
            xaxis_index=1,
            yaxis_index=1,
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                type_="category",
                is_scale=True,
                grid_index=1,
                boundary_gap=False,
                axisline_opts=opts.AxisLineOpts(is_on_zero=False),
                axistick_opts=opts.AxisTickOpts(is_show=False),
                splitline_opts=opts.SplitLineOpts(is_show=False),
                axislabel_opts=opts.LabelOpts(is_show=False),
                split_number=20,
                min_="dataMin",
                max_="dataMax",
            ),
            yaxis_opts=opts.AxisOpts(
                grid_index=1,
                is_scale=True,
                split_number=2,
                axislabel_opts=opts.LabelOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(is_show=False),
                axistick_opts=opts.AxisTickOpts(is_show=False),
                splitline_opts=opts.SplitLineOpts(is_show=False),
            ),
            legend_opts=opts.LegendOpts(is_show=False),
        )
    )

    # Kline And Line
    overlap_kline_line = kline.overlap(line)

    # Grid Overlap + Bar
    grid_chart = Grid()
    grid_chart.add(
        overlap_kline_line,
        grid_opts=opts.GridOpts(pos_left="10%", pos_right="8%", height="50%"),
    )
    grid_chart.add(
        bar,
        grid_opts=opts.GridOpts(
            pos_left="10%", pos_right="8%", pos_top="70%", height="16%"
        ),
    )
    return grid_chart
grid = kline_profession_example()
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b5bbb54732d0479697a2684bc054f051" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b5bbb54732d0479697a2684bc054f051 = echarts.init(
#                     document.getElementById('b5bbb54732d0479697a2684bc054f051'), 'white', {renderer: 'canvas'});
#                 var option_b5bbb54732d0479697a2684bc054f051 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "Dow-Jones index",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 [
#                     2320.26,
#                     2320.26,
#                     2287.3,
#                     2362.94
#                 ],
#                 [
#                     2300,
#                     2291.3,
#                     2288.26,
#                     2308.38
#                 ],
#                 [
#                     2295.35,
#                     2346.5,
#                     2295.35,
#                     2345.92
#                 ],
#                 [
#                     2347.22,
#                     2358.98,
#                     2337.35,
#                     2363.8
#                 ],
#                 [
#                     2360.75,
#                     2382.48,
#                     2347.89,
#                     2383.76
#                 ],
#                 [
#                     2383.43,
#                     2385.42,
#                     2371.23,
#                     2391.82
#                 ],
#                 [
#                     2377.41,
#                     2419.02,
#                     2369.57,
#                     2421.15
#                 ],
#                 [
#                     2425.92,
#                     2428.15,
#                     2417.58,
#                     2440.38
#                 ],
#                 [
#                     2411,
#                     2433.13,
#                     2403.3,
#                     2437.42
#                 ],
#                 [
#                     2432.68,
#                     2334.48,
#                     2427.7,
#                     2441.73
#                 ],
#                 [
#                     2430.69,
#                     2418.53,
#                     2394.22,
#                     2433.89
#                 ],
#                 [
#                     2416.62,
#                     2432.4,
#                     2414.4,
#                     2443.03
#                 ],
#                 [
#                     2441.91,
#                     2421.56,
#                     2418.43,
#                     2444.8
#                 ],
#                 [
#                     2420.26,
#                     2382.91,
#                     2373.53,
#                     2427.07
#                 ],
#                 [
#                     2383.49,
#                     2397.18,
#                     2370.61,
#                     2397.94
#                 ],
#                 [
#                     2378.82,
#                     2325.95,
#                     2309.17,
#                     2378.82
#                 ],
#                 [
#                     2322.94,
#                     2314.16,
#                     2308.76,
#                     2330.88
#                 ],
#                 [
#                     2320.62,
#                     2325.82,
#                     2315.01,
#                     2338.78
#                 ],
#                 [
#                     2313.74,
#                     2293.34,
#                     2289.89,
#                     2340.71
#                 ],
#                 [
#                     2297.77,
#                     2313.22,
#                     2292.03,
#                     2324.63
#                 ],
#                 [
#                     2322.32,
#                     2365.59,
#                     2308.92,
#                     2366.16
#                 ],
#                 [
#                     2364.54,
#                     2359.51,
#                     2330.86,
#                     2369.65
#                 ],
#                 [
#                     2332.08,
#                     2273.4,
#                     2259.25,
#                     2333.54
#                 ],
#                 [
#                     2274.81,
#                     2326.31,
#                     2270.1,
#                     2328.14
#                 ],
#                 [
#                     2333.61,
#                     2347.18,
#                     2321.6,
#                     2351.44
#                 ],
#                 [
#                     2340.44,
#                     2324.29,
#                     2304.27,
#                     2352.02
#                 ],
#                 [
#                     2326.42,
#                     2318.61,
#                     2314.59,
#                     2333.67
#                 ],
#                 [
#                     2314.68,
#                     2310.59,
#                     2296.58,
#                     2320.96
#                 ],
#                 [
#                     2309.16,
#                     2286.6,
#                     2264.83,
#                     2333.29
#                 ],
#                 [
#                     2282.17,
#                     2263.97,
#                     2253.25,
#                     2286.33
#                 ],
#                 [
#                     2255.77,
#                     2270.28,
#                     2253.31,
#                     2276.22
#                 ]
#             ],
#             "itemStyle": {
#                 "color": "#ec0000",
#                 "color0": "#00da3c"
#             }
#         },
#         {
#             "type": "line",
#             "name": "MA2",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "2017-7-1",
#                     "-"
#                 ],
#                 [
#                     "2017-7-2",
#                     "-"
#                 ],
#                 [
#                     "2017-7-3",
#                     2318.9
#                 ],
#                 [
#                     "2017-7-4",
#                     2352.74
#                 ],
#                 [
#                     "2017-7-5",
#                     2370.73
#                 ],
#                 [
#                     "2017-7-6",
#                     2383.95
#                 ],
#                 [
#                     "2017-7-7",
#                     2402.22
#                 ],
#                 [
#                     "2017-7-8",
#                     2423.585
#                 ],
#                 [
#                     "2017-7-9",
#                     2430.64
#                 ],
#                 [
#                     "2017-7-10",
#                     2383.805
#                 ],
#                 [
#                     "2017-7-11",
#                     2376.505
#                 ],
#                 [
#                     "2017-7-12",
#                     2425.465
#                 ],
#                 [
#                     "2017-7-13",
#                     2426.98
#                 ],
#                 [
#                     "2017-7-14",
#                     2402.235
#                 ],
#                 [
#                     "2017-7-15",

# %% [markdown]
# # Page：顺序多图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Line, Page


def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values(), is_selected=False)
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
    )
    return c


def line_base() -> Line:
    c = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
    )
    return c


page = Page()
page.add(bar_base(), line_base())
page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="340791a183ba4b098075b45f644ba131" style="width:900px; height:500px;"></div>
#         <div id="b996a8aedb3241fabc3423ffad9ee224" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_340791a183ba4b098075b45f644ba131 = echarts.init(
#                     document.getElementById('340791a183ba4b098075b45f644ba131'), 'white', {renderer: 'canvas'});
#                 var option_340791a183ba4b098075b45f644ba131 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 91,
#                 20,
#                 85,
#                 113,
#                 68,
#                 137,
#                 104
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 105,
#                 20,
#                 148,
#                 77,
#                 42,
#                 67,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": false
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ]
# };
#                 chart_340791a183ba4b098075b45f644ba131.setOption(option_340791a183ba4b098075b45f644ba131);
#                 var chart_b996a8aedb3241fabc3423ffad9ee224 = echarts.init(
#                     document.getElementById('b996a8aedb3241fabc3423ffad9ee224'), 'white', {renderer: 'canvas'});
#                 var option_b996a8aedb3241fabc3423ffad9ee224 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     71
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     51
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     87
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     132
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     38
#                 ],
#                 [
#                     "VIVO",
#                     62
#                 ],
#                 [
#                     "OPPO",
#                     74
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     111
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     146
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     140
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     147
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     116
#                 ],
#                 [
#                     "VIVO",
#                     79
#                 ],
#                 [
#                     "OPPO",
#                     41
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "so

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line, Page, Pie


def bar_datazoom_slider() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
            datazoom_opts=[opts.DataZoomOpts()],
        )
    )
    return c


def line_markpoint() -> Line:
    c = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis(
            "商家A",
            Faker.values(),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="min")]),
        )
        .add_yaxis(
            "商家B",
            Faker.values(),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max")]),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-MarkPoint"))
    )
    return c


def pie_rosetype() -> Pie:
    v = Faker.choose()
    c = (
        Pie()
        .add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["25%", "50%"],
            rosetype="radius",
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["75%", "50%"],
            rosetype="area",
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
    )
    return c


def grid_mutil_yaxis() -> Grid:
    x_data = ["{}月".format(i) for i in range(1, 13)]
    bar = (
        Bar()
        .add_xaxis(x_data)
        .add_yaxis(
            "蒸发量",
            [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3],
            yaxis_index=0,
            color="#d14a61",
        )
        .add_yaxis(
            "降水量",
            [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3],
            yaxis_index=1,
            color="#5793f3",
        )
        .extend_axis(
            yaxis=opts.AxisOpts(
                name="蒸发量",
                type_="value",
                min_=0,
                max_=250,
                position="right",
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#d14a61")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
            )
        )
        .extend_axis(
            yaxis=opts.AxisOpts(
                type_="value",
                name="温度",
                min_=0,
                max_=25,
                position="left",
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#675bba")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
                splitline_opts=opts.SplitLineOpts(
                    is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
                ),
            )
        )
        .set_global_opts(
            yaxis_opts=opts.AxisOpts(
                name="降水量",
                min_=0,
                max_=250,
                position="right",
                offset=80,
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(color="#5793f3")
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
            ),
            title_opts=opts.TitleOpts(title="Grid-多 Y 轴示例"),
            tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        )
    )

    line = (
        Line()
        .add_xaxis(x_data)
        .add_yaxis(
            "平均温度",
            [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2],
            yaxis_index=2,
            color="#675bba",
            label_opts=opts.LabelOpts(is_show=False),
        )
    )

    bar.overlap(line)
    return Grid().add(
        bar, opts.GridOpts(pos_left="5%", pos_right="20%"), is_control_axis_index=True
    )
c1 = bar_datazoom_slider()
c2 = line_markpoint()
c3 = pie_rosetype()
c4 = grid_mutil_yaxis()
c1.render_notebook()
c2.render_notebook()
c3.render_notebook()
c4.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0b807884905f4a4b96ad2cfd3fdd7377" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0b807884905f4a4b96ad2cfd3fdd7377 = echarts.init(
#                     document.getElementById('0b807884905f4a4b96ad2cfd3fdd7377'), 'white', {renderer: 'canvas'});
#                 var option_0b807884905f4a4b96ad2cfd3fdd7377 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 4,
#                 2,
#                 8,
#                 22,
#                 27,
#                 29,
#                 22,
#                 8,
#                 30,
#                 1,
#                 6,
#                 16,
#                 14,
#                 20,
#                 9,
#                 16,
#                 6,
#                 25,
#                 27,
#                 7,
#                 28,
#                 19,
#                 9,
#                 16,
#                 5,
#                 4,
#                 30,
#                 23,
#                 1,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u6c34\u5e73\uff09"
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false
#         }
#     ]
# };
#                 chart_0b807884905f4a4b96ad2cfd3fdd7377.setOption(option_0b807884905f4a4b96ad2cfd3fdd7377);
#         });
#     </script>
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="51960dd2f7214e899e70a932be9654fa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_51960dd2f7214e899e70a932be9654fa = echarts.init(
#                     document.getElementById('51960dd2f7214e899e70a932be9654fa'), 'white', {renderer: 'canvas'});
#                 var option_51960dd2f7214e899e70a932be9654fa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u54c8\u58eb\u5947",
#                     94
#                 ],
#                 [
#                     "\u8428\u6469\u8036",
#                     71
#                 ],
#                 [
#                     "\u6cf0\u8fea",
#                     87
#                 ],
#                 [
#                     "\u91d1\u6bdb",
#                     87
#                 ],
#                 [
#                     "\u7267\u7f8a\u72ac",
#                     136
#                 ],
#                 [
#                     "\u5409\u5a03\u5a03",
#                     110
#                 ],
#                 [
#                     "\u67ef\u57fa",
#                     40
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "min"
#                     }
#                 ]
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u54c8\u58eb\u5947",
#                     40
#                 ],
#                 [
#                     "\u8428\u6469\u8036",
#                     95
#                 ],
#                 [
#                     "\u6cf0\u8fea",
#                     83
#                 ],
#                 [
#                     "\u91d1\u6bdb",
#                     71
#                 ],
#                 [
#                     "\u7267\u7f8a\u72ac",
#                     103
#                 ],
#                 [
#                     "\u5409\u5a03\u5a03",
#                     84
#                 ],
#                 [
#                     "\u67ef\u57fa",
#                     63
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "max"
#                     }
#                 ]
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-MarkPoint"
#         }
#     ]
# };
#                 chart_51960dd2f7214e899e70a932be9654fa.setOption(option_51960dd2f7214e899e70a932be9654fa);
#         });
#     </script>
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a40dcb718ae74b61b9c16c8663ef73c8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a40dcb718ae74b61b9c16c8663ef73c8 = echarts.init(
#                     document.getElementById('a40dcb718ae74b61b9c16c8663ef73c8'), 'white', {renderer: 'canvas'});
#                 var option_a40dcb718ae74b61b9c16c8663ef73c8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 135
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 119
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 127
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_a40dcb718ae74b61b9c16c8663ef73c8.setOption(option_a40dcb718ae74b61b9c16c8663ef73c8);
#         });
#     </script>
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="493b810f56b6498481b7d512d6b411dd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_493b810f56b6498481b7d512d6b411dd = echarts.init(
#                     document.getElementById('493b810f56b6498481b7d512d6b411dd'), 'white', {renderer: 'canvas'});
#                 var option_493b810f56b6498481b7d512d6b411dd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#5793f3",
#         "#d14a61",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "yAxisIndex": 0,
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "yAxisIndex": 1,
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u6e29\u5ea6",
#             "connectNulls": false,
#             "yAxisIndex": 2,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1\u6708",
#                     2.0
#                 ],
#                 [
#                     "2\u6708",
#                     2.2
#                 ],
#                 [
#                     "3\u6708",
#                     3.3
#                 ],
#                 [
#                     "4\u6708",
#                     4.5
#                 ],
#                 [
#                     "5\u6708",
#                     6.3
#                 ],
#                 [
#                     "6\u6708",
#                     10.2
#                 ],
#                 [
#                     "7\u6708",
#                     20.3
#                 ],
#                 [
#                     "8\u6708",
#                     23.4
#                 ],
#                 [
#                     "9\u6708",
#                     23.0
#                 ],
#                 [
#                     "10\u6708",
#                     16.5
#                 ],
#                 [
#                     "11\u6708",
#                     12.0
#                 ],
#                 [
#                     "12\u6708",
#                     6.2
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u84b8\u53d1\u91cf",
#                 "\u964d\u6c34\u91cf",
#                 "\u5e73\u5747\u6e29\u5ea6"
#             ],
#             "selected": {
#                 "\u84b8\u53d1\u91cf": true,
#                 "\u964d\u6c34\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708",
#                 "8\u6708",
#                 "9\u6708",
#                 "10\u6708",
#                 "11\u6708",
#                 "12\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u964d\u6c34\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#5793f3"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} ml"
#             },
#             "inverse": false,
#             "position": "right",
#             "offset": 80,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 250,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "\u84b8\u53d1\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#d14a61"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} ml"
#             },
#             "inverse": false,
#             "position": "right",
#             "offset": 0,
#             "splitNumber": 5,

# %%
# page = Page()
# page = Page(layout=Page.DraggablePageLayout)
page = Page(layout=Page.SimplePageLayout)
# 需要自行调整每个 chart 的 height/width，显示效果在不同的显示器上可能不同
page.add(bar_datazoom_slider(), line_markpoint(), pie_rosetype(), grid_mutil_yaxis())
page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="eab69a44032d4d989f3dc5505bc2c63d" style="width:900px; height:500px;"></div>
#         <div id="43abb67481c94ac3865ab041187a8e58" style="width:900px; height:500px;"></div>
#         <div id="46672c9cb3d440bb88add911c583c312" style="width:900px; height:500px;"></div>
#         <div id="423b86010fdb404aa9d3d40d59aeb3c5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_eab69a44032d4d989f3dc5505bc2c63d = echarts.init(
#                     document.getElementById('eab69a44032d4d989f3dc5505bc2c63d'), 'white', {renderer: 'canvas'});
#                 var option_eab69a44032d4d989f3dc5505bc2c63d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 4,
#                 2,
#                 8,
#                 22,
#                 27,
#                 29,
#                 22,
#                 8,
#                 30,
#                 1,
#                 6,
#                 16,
#                 14,
#                 20,
#                 9,
#                 16,
#                 6,
#                 25,
#                 27,
#                 7,
#                 28,
#                 19,
#                 9,
#                 16,
#                 5,
#                 4,
#                 30,
#                 23,
#                 1,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u6c34\u5e73\uff09"
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false
#         }
#     ]
# };
#                 chart_eab69a44032d4d989f3dc5505bc2c63d.setOption(option_eab69a44032d4d989f3dc5505bc2c63d);
#                 var chart_43abb67481c94ac3865ab041187a8e58 = echarts.init(
#                     document.getElementById('43abb67481c94ac3865ab041187a8e58'), 'white', {renderer: 'canvas'});
#                 var option_43abb67481c94ac3865ab041187a8e58 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     37
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     122
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     51
#                 ],
#                 [
#                     "\u7eff\u8336",
#                     83
#                 ],
#                 [
#                     "\u5976\u8336",
#                     145
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     118
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     87
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {

# %% [markdown]
# # Tab：选项卡多图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Tab, Pie, Line
from pyecharts.components import Table


def bar_datazoom_slider() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
            datazoom_opts=[opts.DataZoomOpts()],
        )
    )
    return c


def line_markpoint() -> Line:
    c = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis(
            "商家A",
            Faker.values(),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="min")]),
        )
        .add_yaxis(
            "商家B",
            Faker.values(),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max")]),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-MarkPoint"))
    )
    return c


def pie_rosetype() -> Pie:
    v = Faker.choose()
    c = (
        Pie()
        .add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["25%", "50%"],
            rosetype="radius",
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["75%", "50%"],
            rosetype="area",
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
    )
    return c


def table_base() -> Table:
    table = Table()

    headers = ["City name", "Area", "Population", "Annual Rainfall"]
    rows = [
        ["Brisbane", 5905, 1857594, 1146.4],
        ["Adelaide", 1295, 1158259, 600.5],
        ["Darwin", 112, 120900, 1714.7],
        ["Hobart", 1357, 205556, 619.5],
        ["Sydney", 2058, 4336374, 1214.8],
        ["Melbourne", 1566, 3806092, 646.9],
        ["Perth", 5386, 1554769, 869.4],
    ]
    table.add(headers, rows).set_global_opts(
        title_opts=opts.ComponentTitleOpts(title="Table")
    )
    return table

tab = Tab()
tab.add(bar_datazoom_slider(), "bar-example")
tab.add(line_markpoint(), "line-example")
tab.add(pie_rosetype(), "pie-example")
tab.add(table_base(), "table-example")
tab.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
#             padding: 6px 12px;
#             border-top: none;
#         }
#     </style>
# <div class="tab">
#             <button class="tablinks" onclick="showChart(event, 'efd6d26cb6ab424dab1df06b254138f7')">bar-example</button>
#             <button class="tablinks" onclick="showChart(event, '380739985bf14cd29fa3b9b0be8b5835')">line-example</button>
#             <button class="tablinks" onclick="showChart(event, 'ba47b9f68d0e462b904e3c6a398a5846')">pie-example</button>
#             <button class="tablinks" onclick="showChart(event, '5e1cb98b084b48adaba54f6d3e45e157')">table-example</button>
#     </div>
#
#         <div id="efd6d26cb6ab424dab1df06b254138f7" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="380739985bf14cd29fa3b9b0be8b5835" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="ba47b9f68d0e462b904e3c6a398a5846" class="chart-container" style="width:900px; height:500px;"></div>
#                 <style>
#             .fl-table {
#                 margin: 20px;
#                 border-radius: 5px;
#                 font-size: 12px;
#                 border: none;
#                 border-collapse: collapse;
#                 max-width: 100%;
#                 white-space: nowrap;
#                 word-break: keep-all;
#             }
#
#             .fl-table th {
#                 text-align: left;
#                 font-size: 20px;
#             }
#
#             .fl-table tr {
#                 display: table-row;
#                 vertical-align: inherit;
#                 border-color: inherit;
#             }
#
#             .fl-table tr:hover td {
#                 background: #00d1b2;
#                 color: #F8F8F8;
#             }
#
#             .fl-table td, .fl-table th {
#                 border-style: none;
#                 border-top: 1px solid #dbdbdb;
#                 border-left: 1px solid #dbdbdb;
#                 border-bottom: 3px solid #dbdbdb;
#                 border-right: 1px solid #dbdbdb;
#                 padding: .5em .55em;
#                 font-size: 15px;
#             }
#
#             .fl-table td {
#                 border-style: none;
#                 font-size: 15px;
#                 vertical-align: center;
#                 border-bottom: 1px solid #dbdbdb;
#                 border-left: 1px solid #dbdbdb;
#                 border-right: 1px solid #dbdbdb;
#                 height: 30px;
#             }
#
#             .fl-table tr:nth-child(even) {
#                 background: #F8F8F8;
#             }
#         </style>
#         <div id="5e1cb98b084b48adaba54f6d3e45e157" class="chart-container" style="">
#             <p class="title" style="font-size: 18px; font-weight:bold;" > Table</p>
#             <p class="subtitle" style="font-size: 12px;" > </p>
#             <table class="fl-table">
#     <tr>
#         <th>City name</th>
#         <th>Area</th>
#         <th>Population</th>
#         <th>Annual Rainfall</th>
#     </tr>
#     <tr>
#         <td>Brisbane</td>
#         <td>5905</td>
#         <td>1857594</td>
#         <td>1146.4</td>
#     </tr>
#     <tr>
#         <td>Adelaide</td>
#         <td>1295</td>
#         <td>1158259</td>
#         <td>600.5</td>
#     </tr>
#     <tr>
#         <td>Darwin</td>
#         <td>112</td>
#         <td>120900</td>
#         <td>1714.7</td>
#     </tr>
#     <tr>
#         <td>Hobart</td>
#         <td>1357</td>
#         <td>205556</td>
#         <td>619.5</td>
#     </tr>
#     <tr>
#         <td>Sydney</td>
#         <td>2058</td>
#         <td>4336374</td>
#         <td>1214.8</td>
#     </tr>
#     <tr>
#         <td>Melbourne</td>
#         <td>1566</td>
#         <td>3806092</td>
#         <td>646.9</td>
#     </tr>
#     <tr>
#         <td>Perth</td>
#         <td>5386</td>
#         <td>1554769</td>
#         <td>869.4</td>
#     </tr>
# </table>
#         </div>
#
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_efd6d26cb6ab424dab1df06b254138f7 = echarts.init(
#                     document.getElementById('efd6d26cb6ab424dab1df06b254138f7'), 'white', {renderer: 'canvas'});
#                 var option_efd6d26cb6ab424dab1df06b254138f7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 4,
#                 2,
#                 8,
#                 22,
#                 27,
#                 29,
#                 22,
#                 8,
#                 30,
#                 1,
#                 6,
#                 16,
#                 14,
#                 20,
#                 9,
#                 16,
#                 6,
#                 25,
#                 27,
#                 7,
#                 28,
#                 19,
#                 9,
#                 16,
#                 5,
#                 4,
#                 30,
#                 23,
#                 1,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",

# %% [markdown]
# # Timeline：时间线轮播多图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Page, Pie, Timeline, Map


def timeline_bar() -> Timeline:
    x = Faker.choose()
    tl = Timeline()
    for i in range(2015, 2020):
        bar = (
            Bar()
            .add_xaxis(x)
            .add_yaxis("商家A", Faker.values())
            .add_yaxis("商家B", Faker.values())
            .set_global_opts(title_opts=opts.TitleOpts("某商店{}年营业额".format(i)))
        )
        tl.add(bar, "{}年".format(i))
    return tl
tl = timeline_bar()
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9240652890d24905adf67aea9e046a4f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9240652890d24905adf67aea9e046a4f = echarts.init(
#                     document.getElementById('9240652890d24905adf67aea9e046a4f'), 'white', {renderer: 'canvas'});
#                 var option_9240652890d24905adf67aea9e046a4f = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u5546\u5bb6A",
#                 "data": [
#                     126,
#                     89,
#                     134,
#                     72,
#                     100,
#                     138,
#                     26
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "\u5546\u5bb6B",
#                 "data": [
#                     49,
#                     96,
#                     54,
#                     131,
#                     59,
#                     95,
#                     90
#                 ],
#                 "barCategoryGap": "20%",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u8349\u8393",
#                     "\u8292\u679c",
#                     "\u8461\u8404",
#                     "\u96ea\u68a8",
#                     "\u897f\u74dc",
#                     "\u67e0\u6aac",
#                     "\u8f66\u5398\u5b50"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5546\u5bb6A",
#                         "\u5546\u5bb6B"
#                     ],
#                     "selected": {
#                         "\u5546\u5bb6A": true,
#                         "\u5546\u5bb6B": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         79,
#                         81,
#                         68,
#                         47,
#                         70,
#                         133,
#                         54
#                     ]
#                 },
#                 {
#                     "data": [
#                         51,
#                         87,
#                         88,
#                         137,
#                         29,
#                         94,
#                         76
#                     ]
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     },
#                     "data": [
#                         "\u8349\u8393",
#                         "\u8292\u679c",
#                         "\u8461\u8404",
#                         "\u96ea\u68a8",
#                         "\u897f\u74dc",
#                         "\u67e0\u6aac",
#                         "\u8f66\u5398\u5b50"
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u67d0\u5546\u5e972015\u5e74\u8425\u4e1a\u989d"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5546\u5bb6A",
#                         "\u5546\u5bb6B"
#                     ],
#                     "selected": {
#                         "\u5546\u5bb6A": true,
#                         "\u5546\u5bb6B": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         119,
#                         126,
#                         28,
#                         57,
#                         122,
#                         132,
#                         23
#                     ]
#                 },
#                 {
#                     "data": [
#                         69,
#                         67,
#                         139,
#                         112,
#                         50,
#                         111,
#                         125
#                     ]
#                 }

# %%
def timeline_pie() -> Timeline:
    attr = Faker.choose()
    tl = Timeline()
    for i in range(2015, 2020):
        pie = (
            Pie()
            .add(
                "商家A",
                [list(z) for z in zip(attr, Faker.values())],
                rosetype="radius",
                radius=["30%", "55%"],
            )
            .set_global_opts(title_opts=opts.TitleOpts("某商店{}年营业额".format(i)))
        )
        tl.add(pie, "{}年".format(i))
    return tl
tl = timeline_pie()
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="eba358925570431992251706f5db759a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_eba358925570431992251706f5db759a = echarts.init(
#                     document.getElementById('eba358925570431992251706f5db759a'), 'white', {renderer: 'canvas'});
#                 var option_eba358925570431992251706f5db759a = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "\u5546\u5bb6A",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\u54c8\u58eb\u5947",
#                         "value": 105
#                     },
#                     {
#                         "name": "\u8428\u6469\u8036",
#                         "value": 70
#                     },
#                     {
#                         "name": "\u6cf0\u8fea",
#                         "value": 78
#                     },
#                     {
#                         "name": "\u91d1\u6bdb",
#                         "value": 54
#                     },
#                     {
#                         "name": "\u7267\u7f8a\u72ac",
#                         "value": 62
#                     },
#                     {
#                         "name": "\u5409\u5a03\u5a03",
#                         "value": 67
#                     },
#                     {
#                         "name": "\u67ef\u57fa",
#                         "value": 66
#                     }
#                 ],
#                 "radius": [
#                     "30%",
#                     "55%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "roseType": "radius",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u54c8\u58eb\u5947",
#                         "\u8428\u6469\u8036",
#                         "\u6cf0\u8fea",
#                         "\u91d1\u6bdb",
#                         "\u7267\u7f8a\u72ac",
#                         "\u5409\u5a03\u5a03",
#                         "\u67ef\u57fa"
#                     ],
#                     "selected": {},
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         {
#                             "name": "\u54c8\u58eb\u5947",
#                             "value": 92
#                         },
#                         {
#                             "name": "\u8428\u6469\u8036",
#                             "value": 134
#                         },
#                         {
#                             "name": "\u6cf0\u8fea",
#                             "value": 30
#                         },
#                         {
#                             "name": "\u91d1\u6bdb",
#                             "value": 142
#                         },
#                         {
#                             "name": "\u7267\u7f8a\u72ac",
#                             "value": 118
#                         },
#                         {
#                             "name": "\u5409\u5a03\u5a03",
#                             "value": 31
#                         },
#                         {
#                             "name": "\u67ef\u57fa",
#                             "value": 57
#                         }
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u67d0\u5546\u5e972015\u5e74\u8425\u4e1a\u989d"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u54c8\u58eb\u5947",
#                         "\u8428\u6469\u8036",
#                         "\u6cf0\u8fea",
#                         "\u91d1\u6bdb",
#                         "\u7267\u7f8a\u72ac",
#                         "\u5409\u5a03\u5a03",
#                         "\u67ef\u57fa"
#                     ],
#                     "selected": {},
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         {
#                             "name": "\u54c8\u58eb\u5947",
#                             "value": 110
#                         },
#                         {
#                             "name": "\u8428\u6469\u8036",
#                             "value": 62
#                         },
#                         {
#                             "name": "\u6cf0\u8fea",
#                             "value": 50
#                         },
#                         {
#                             "name": "\u91d1\u6bdb",
#                             "value": 107
#                         },
#                         {
#                             "name": "\u7267\u7f8a\u72ac",
#                             "value": 145
#                         },
#                         {
#                             "name": "\u5409\u5a03\u5a03",
#                             "value": 52
#                         },
#                         {
#                             "name": "\u67ef\u57fa",
#                             "value": 78
#                         }
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\u67d0\u5546\u5e972016\u5e74\u8425\u4e1a\u989d"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",

# %%
def timeline_map() -> Timeline:
    tl = Timeline()
    for i in range(2015, 2020):
        map0 = (
            Map()
            .add(
                "商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china"
            )
            .set_global_opts(
                title_opts=opts.TitleOpts(title="Map-{}年某些数据".format(i)),
                visualmap_opts=opts.VisualMapOpts(max_=200),
            )
        )
        tl.add(map0, "{}年".format(i))
    return tl
tl = timeline_map()
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="e45cf5880b57455c8c74eb6f1036fce6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_e45cf5880b57455c8c74eb6f1036fce6 = echarts.init(
#                     document.getElementById('e45cf5880b57455c8c74eb6f1036fce6'), 'white', {renderer: 'canvas'});
#                 var option_e45cf5880b57455c8c74eb6f1036fce6 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "map",
#                 "name": "\u5546\u5bb6A",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "mapType": "china",
#                 "data": [
#                     {
#                         "name": "\u5e7f\u4e1c",
#                         "value": 46
#                     },
#                     {
#                         "name": "\u5317\u4eac",
#                         "value": 86
#                     },
#                     {
#                         "name": "\u4e0a\u6d77",
#                         "value": 91
#                     },
#                     {
#                         "name": "\u6c5f\u897f",
#                         "value": 130
#                     },
#                     {
#                         "name": "\u6e56\u5357",
#                         "value": 90
#                     },
#                     {
#                         "name": "\u6d59\u6c5f",
#                         "value": 135
#                     },
#                     {
#                         "name": "\u6c5f\u82cf",
#                         "value": 38
#                     }
#                 ],
#                 "roam": true,
#                 "zoom": 1,
#                 "showLegendSymbol": true,
#                 "emphasis": {}
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "visualMap": {
#             "show": true,
#             "type": "continuous",
#             "min": 0,
#             "max": 200,
#             "inRange": {
#                 "color": [
#                     "#50a3ba",
#                     "#eac763",
#                     "#d94e5d"
#                 ]
#             },
#             "calculable": true,
#             "splitNumber": 5,
#             "orient": "vertical",
#             "showLabel": true
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5546\u5bb6A"
#                     ],
#                     "selected": {
#                         "\u5546\u5bb6A": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         {
#                             "name": "\u5e7f\u4e1c",
#                             "value": 137
#                         },
#                         {
#                             "name": "\u5317\u4eac",
#                             "value": 74
#                         },
#                         {
#                             "name": "\u4e0a\u6d77",
#                             "value": 92
#                         },
#                         {
#                             "name": "\u6c5f\u897f",
#                             "value": 55
#                         },
#                         {
#                             "name": "\u6e56\u5357",
#                             "value": 24
#                         },
#                         {
#                             "name": "\u6d59\u6c5f",
#                             "value": 81
#                         },
#                         {
#                             "name": "\u6c5f\u82cf",
#                             "value": 91
#                         }
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "Map-2015\u5e74\u67d0\u4e9b\u6570\u636e"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "visualMap": {
#                 "show": true,
#                 "type": "continuous",
#                 "min": 0,
#                 "max": 200,
#                 "inRange": {
#                     "color": [
#                         "#50a3ba",
#                         "#eac763",
#                         "#d94e5d"
#                     ]
#                 },
#                 "calculable": true,
#                 "splitNumber": 5,
#                 "orient": "vertical",
#                 "showLabel": true
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u5546\u5bb6A"
#                     ],
#                     "selected": {
#                         "\u5546\u5bb6A": true
#                     },
#                     "show": true
#                 }
#             ],
#             "series": [
#                 {
#                     "data": [
#                         {
#                             "name": "\u5e7f\u4e1c",
#                             "value": 128
#                         },
#                         {
#                             "name": "\u5317\u4eac",
#                             "value": 112
#                         },
#                         {
#                             "name": "\u4e0a\u6d77",
#                             "value": 127
#                         },
#                         {
#                             "name": "\u6c5f\u897f",
#                             "value": 57
#                         },
#                         {
#                             "name": "\u6e56\u5357",
#                             "value": 136
#                         },
#                         {
#                             "name": "\u6d59\u6c5f",
#                             "value": 116
#                         },
#                         {
#                             "name": "\u6c5f\u82cf",
#                             "value": 90
#                         }
#                     ]
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "Map-2016\u5e74\u67d0\u4e9b\u6570\u636e"
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "textStyle": {
