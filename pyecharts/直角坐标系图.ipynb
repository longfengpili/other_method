# %% [markdown]
# # Bar：柱状图/条形图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar


def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
#         .reversal_axis()
    )
    return c

c = bar_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="12d15860054f420d83df448e6c90b877" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_12d15860054f420d83df448e6c90b877 = echarts.init(
#                     document.getElementById('12d15860054f420d83df448e6c90b877'), 'white', {renderer: 'canvas'});
#                 var option_12d15860054f420d83df448e6c90b877 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 25,
#                 20,
#                 73,
#                 112,
#                 120,
#                 141,
#                 144
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 108,
#                 135,
#                 128,
#                 102,
#                 139,
#                 83,
#                 94
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ]
# };
#                 chart_12d15860054f420d83df448e6c90b877.setOption(option_12d15860054f420d83df448e6c90b877);
#         });
#     </script>

# %%
from pyecharts.commons.utils import JsCode

def bar_border_radius():
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), category_gap="60%")
        .set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-渐变圆柱"))
    )
    return c
c = bar_border_radius()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4bdf6c0c68a74c8b848563ee757f915c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4bdf6c0c68a74c8b848563ee757f915c = echarts.init(
#                     document.getElementById('4bdf6c0c68a74c8b848563ee757f915c'), 'white', {renderer: 'canvas'});
#                 var option_4bdf6c0c68a74c8b848563ee757f915c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 33,
#                 61,
#                 141,
#                 27,
#                 125,
#                 108,
#                 53
#             ],
#             "barCategoryGap": "60%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(0, 244, 255, 1)'                }, {                    offset: 1,                    color: 'rgba(0, 77, 167, 1)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u6e10\u53d8\u5706\u67f1"
#         }
#     ]
# };
#                 chart_4bdf6c0c68a74c8b848563ee757f915c.setOption(option_4bdf6c0c68a74c8b848563ee757f915c);
#         });
#     </script>

# %%
def bar_base_with_animation() -> Bar:
    c = (
        Bar(
            init_opts=opts.InitOpts(
                animation_opts=opts.AnimationOpts(
                    animation_delay=1000, animation_easing="elasticOut"
                )
            )
        )
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-动画配置基本示例", subtitle="我是副标题")
        )
    )
    return c

c = bar_base_with_animation()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="34df6c8e2fef467895b9976b2c679457" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_34df6c8e2fef467895b9976b2c679457 = echarts.init(
#                     document.getElementById('34df6c8e2fef467895b9976b2c679457'), 'white', {renderer: 'canvas'});
#                 var option_34df6c8e2fef467895b9976b2c679457 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "elasticOut",
#     "animationDelay": 1000,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 67,
#                 41,
#                 96,
#                 69,
#                 60,
#                 57,
#                 112
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 79,
#                 27,
#                 72,
#                 118,
#                 36,
#                 50,
#                 106
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u52a8\u753b\u914d\u7f6e\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ]
# };
#                 chart_34df6c8e2fef467895b9976b2c679457.setOption(option_34df6c8e2fef467895b9976b2c679457);
#         });
#     </script>

# %%
def bar_base_with_custom_background_image() -> Bar:
    c = (
        Bar(
            init_opts=opts.InitOpts(
                bg_color={
                    "type": "pattern",
                    "image": JsCode("img"),
                    "repeat": "no-repeat",
                }
            )
        )
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title="Bar-背景图基本示例",
                subtitle="我是副标题",
                title_textstyle_opts=opts.TextStyleOpts(color="white"),
            )
        )
    )
    c.add_js_funcs(
        """
        var img = new Image(); img.src = 'http://pic38.nipic.com/20140228/2457331_083845176000_2.jpg';
        """
    )
    return c

c = bar_base_with_custom_background_image()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1bfe555e614143f9ba595f2f5731c296" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1bfe555e614143f9ba595f2f5731c296 = echarts.init(
#                     document.getElementById('1bfe555e614143f9ba595f2f5731c296'), 'white', {renderer: 'canvas'});
#
#         var img = new Image(); img.src = 'http://pic38.nipic.com/20140228/2457331_083845176000_2.jpg';
#
#                 var option_1bfe555e614143f9ba595f2f5731c296 = {
#     "backgroundColor": {
#         "type": "pattern",
#         "image": img,
#         "repeat": "no-repeat"
#     },
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 21,
#                 62,
#                 92,
#                 57,
#                 87,
#                 82,
#                 46
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 144,
#                 100,
#                 112,
#                 145,
#                 126,
#                 148,
#                 51
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u80cc\u666f\u56fe\u57fa\u672c\u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898",
#             "textStyle": {
#                 "color": "white"
#             }
#         }
#     ]
# };
#                 chart_1bfe555e614143f9ba595f2f5731c296.setOption(option_1bfe555e614143f9ba595f2f5731c296);
#         });
#     </script>

# %%
from pyecharts.globals import ThemeType
def bar_base_dict_config() -> Bar:
    c = (
        Bar({"theme": ThemeType.MACARONS})
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts={"text": "Bar-通过 dict 进行配置", "subtext": "我也是通过 dict 进行配置的"}
        )
    )
    return c

c = bar_base_dict_config()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="1b7a6bf1bcd04ddaa5dbc8be7a52066d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_1b7a6bf1bcd04ddaa5dbc8be7a52066d = echarts.init(
#                     document.getElementById('1b7a6bf1bcd04ddaa5dbc8be7a52066d'), 'macarons', {renderer: 'canvas'});
#                 var option_1b7a6bf1bcd04ddaa5dbc8be7a52066d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 51,
#                 119,
#                 82,
#                 61,
#                 121,
#                 70,
#                 113
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 112,
#                 74,
#                 67,
#                 22,
#                 121,
#                 71,
#                 145
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": {
#         "text": "Bar-\u901a\u8fc7 dict \u8fdb\u884c\u914d\u7f6e",
#         "subtext": "\u6211\u4e5f\u662f\u901a\u8fc7 dict \u8fdb\u884c\u914d\u7f6e\u7684"
#     }
# };
#                 chart_1b7a6bf1bcd04ddaa5dbc8be7a52066d.setOption(option_1b7a6bf1bcd04ddaa5dbc8be7a52066d);
#         });
#     </script>

# %%
def bar_is_selected() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values(), is_selected=False)
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-默认取消显示某 Series"))
    )
    return c
c = bar_is_selected()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a0a327f52356416492a57bf84890f1ff" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a0a327f52356416492a57bf84890f1ff = echarts.init(
#                     document.getElementById('a0a327f52356416492a57bf84890f1ff'), 'white', {renderer: 'canvas'});
#                 var option_a0a327f52356416492a57bf84890f1ff = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 40,
#                 45,
#                 148,
#                 96,
#                 149,
#                 56,
#                 56
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 63,
#                 102,
#                 85,
#                 145,
#                 102,
#                 83,
#                 112
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": false
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u9ed8\u8ba4\u53d6\u6d88\u663e\u793a\u67d0 Series"
#         }
#     ]
# };
#                 chart_a0a327f52356416492a57bf84890f1ff.setOption(option_a0a327f52356416492a57bf84890f1ff);
#         });
#     </script>

# %%
def bar_toolbox() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-显示 ToolBox"),
            toolbox_opts=opts.ToolboxOpts(),
            legend_opts=opts.LegendOpts(is_show=False)
        )
    )
    return c
c = bar_toolbox()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7206502068af4f5c84ba76b90d224dd8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7206502068af4f5c84ba76b90d224dd8 = echarts.init(
#                     document.getElementById('7206502068af4f5c84ba76b90d224dd8'), 'white', {renderer: 'canvas'});
#                 var option_7206502068af4f5c84ba76b90d224dd8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 47,
#                 41,
#                 48,
#                 47,
#                 136,
#                 141,
#                 27
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 130,
#                 58,
#                 29,
#                 99,
#                 128,
#                 78,
#                 37
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u663e\u793a ToolBox"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image",
#                 "type": "png"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view",
#                 "readOnly": false
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "data zoom",
#                     "back": "data zoom restore"
#                 }
#             }
#         }
#     }
# };
#                 chart_7206502068af4f5c84ba76b90d224dd8.setOption(option_7206502068af4f5c84ba76b90d224dd8);
#         });
#     </script>

# %%
def bar_same_series_gap() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), category_gap="80%")
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-单系列柱间距离"))
    )
    return c

c = bar_same_series_gap()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c03850004e7f47d186601f4f0c876603" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c03850004e7f47d186601f4f0c876603 = echarts.init(
#                     document.getElementById('c03850004e7f47d186601f4f0c876603'), 'white', {renderer: 'canvas'});
#                 var option_c03850004e7f47d186601f4f0c876603 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 130,
#                 109,
#                 94,
#                 60,
#                 49,
#                 131,
#                 59
#             ],
#             "barCategoryGap": "80%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u5355\u7cfb\u5217\u67f1\u95f4\u8ddd\u79bb"
#         }
#     ]
# };
#                 chart_c03850004e7f47d186601f4f0c876603.setOption(option_c03850004e7f47d186601f4f0c876603);
#         });
#     </script>

# %%
def bar_different_series_gap() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), gap="0%")
        .add_yaxis("商家B", Faker.values(), gap="0%")
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-不同系列柱间距离"),
        )
    )
    return c

c = bar_different_series_gap()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0a3a57e15f9a406799ca0a682d18917e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0a3a57e15f9a406799ca0a682d18917e = echarts.init(
#                     document.getElementById('0a3a57e15f9a406799ca0a682d18917e'), 'white', {renderer: 'canvas'});
#                 var option_0a3a57e15f9a406799ca0a682d18917e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 34,
#                 138,
#                 116,
#                 62,
#                 93,
#                 140,
#                 147
#             ],
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 124,
#                 55,
#                 136,
#                 68,
#                 48,
#                 109,
#                 126
#             ],
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u4e0d\u540c\u7cfb\u5217\u67f1\u95f4\u8ddd\u79bb"
#         }
#     ]
# };
#                 chart_0a3a57e15f9a406799ca0a682d18917e.setOption(option_0a3a57e15f9a406799ca0a682d18917e);
#         });
#     </script>

# %%
def bar_yaxis_formatter() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-Y 轴 formatter"),
            yaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /月")
            ),
        )
    )
    return c

c = bar_yaxis_formatter()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2cedd8d1ab784e4099c64c3402e3d10b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2cedd8d1ab784e4099c64c3402e3d10b = echarts.init(
#                     document.getElementById('2cedd8d1ab784e4099c64c3402e3d10b'), 'white', {renderer: 'canvas'});
#                 var option_2cedd8d1ab784e4099c64c3402e3d10b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 61,
#                 23,
#                 101,
#                 32,
#                 135,
#                 137,
#                 131
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 116,
#                 58,
#                 125,
#                 46,
#                 67,
#                 124,
#                 25
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u6708"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Y \u8f74 formatter"
#         }
#     ]
# };
#                 chart_2cedd8d1ab784e4099c64c3402e3d10b.setOption(option_2cedd8d1ab784e4099c64c3402e3d10b);
#         });
#     </script>

# %%
def bar_xyaxis_name() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-XY 轴名称", subtitle='ttt'),
            yaxis_opts=opts.AxisOpts(name="我是 Y 轴"),
            xaxis_opts=opts.AxisOpts(name="我是 X 轴"),
        )
    )
    return c

c = bar_xyaxis_name()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e6dcf4f9ae654703af5087fcb85b3b92" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e6dcf4f9ae654703af5087fcb85b3b92 = echarts.init(
#                     document.getElementById('e6dcf4f9ae654703af5087fcb85b3b92'), 'white', {renderer: 'canvas'});
#                 var option_e6dcf4f9ae654703af5087fcb85b3b92 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 35,
#                 101,
#                 118,
#                 104,
#                 140,
#                 118,
#                 72
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 119,
#                 138,
#                 132,
#                 96,
#                 101,
#                 89,
#                 66
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u6211\u662f X \u8f74",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u6211\u662f Y \u8f74",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-XY \u8f74\u540d\u79f0",
#             "subtext": "ttt"
#         }
#     ]
# };
#                 chart_e6dcf4f9ae654703af5087fcb85b3b92.setOption(option_e6dcf4f9ae654703af5087fcb85b3b92);
#         });
#     </script>

# %%
def bar_reversal_axis() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(position="inside"))
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-翻转 XY 轴"))
    )
    return c

c = bar_reversal_axis()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d571597f701646f4a76aa53018f183db" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d571597f701646f4a76aa53018f183db = echarts.init(
#                     document.getElementById('d571597f701646f4a76aa53018f183db'), 'white', {renderer: 'canvas'});
#                 var option_d571597f701646f4a76aa53018f183db = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 76,
#                 110,
#                 92,
#                 133,
#                 97,
#                 58,
#                 101
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 55,
#                 74,
#                 50,
#                 89,
#                 25,
#                 40,
#                 117
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u7ffb\u8f6c XY \u8f74"
#         }
#     ]
# };
#                 chart_d571597f701646f4a76aa53018f183db.setOption(option_d571597f701646f4a76aa53018f183db);
#         });
#     </script>

# %%
def bar_stack0() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), stack="stack1")
        .add_yaxis("商家B", Faker.values(), stack="stack1")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据（全部）"))
    )
    return c

c = bar_stack0()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d32a16913053438abed07b18a1d92a3f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d32a16913053438abed07b18a1d92a3f = echarts.init(
#                     document.getElementById('d32a16913053438abed07b18a1d92a3f'), 'white', {renderer: 'canvas'});
#                 var option_d32a16913053438abed07b18a1d92a3f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 44,
#                 35,
#                 143,
#                 58,
#                 118,
#                 91,
#                 25
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 48,
#                 81,
#                 37,
#                 36,
#                 107,
#                 51,
#                 83
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u5806\u53e0\u6570\u636e\uff08\u5168\u90e8\uff09"
#         }
#     ]
# };
#                 chart_d32a16913053438abed07b18a1d92a3f.setOption(option_d32a16913053438abed07b18a1d92a3f);
#         });
#     </script>

# %%
def bar_stack1() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), stack="stack1", gap='0%')
        .add_yaxis("商家B", Faker.values(), stack="stack1", gap='0%')
        .add_yaxis("商家C", Faker.values(), gap='0%')
        .add_yaxis("商家D", Faker.values(), stack="stack2", gap='0%')
        .add_yaxis("商家E", Faker.values(), stack="stack2", gap='0%')       
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据（部分）"))
    )
    return c

c = bar_stack1()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0935791836cb40dea6eab33f2b09c27b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0935791836cb40dea6eab33f2b09c27b = echarts.init(
#                     document.getElementById('0935791836cb40dea6eab33f2b09c27b'), 'white', {renderer: 'canvas'});
#                 var option_0935791836cb40dea6eab33f2b09c27b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 25,
#                 125,
#                 119,
#                 30,
#                 45,
#                 36,
#                 29
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 92,
#                 128,
#                 91,
#                 106,
#                 139,
#                 77,
#                 76
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 64,
#                 125,
#                 124,
#                 140,
#                 136,
#                 44,
#                 30
#             ],
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 62,
#                 62,
#                 76,
#                 65,
#                 35,
#                 93,
#                 37
#             ],
#             "stack": "stack2",
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6E",
#             "data": [
#                 125,
#                 77,
#                 135,
#                 116,
#                 132,
#                 111,
#                 138
#             ],
#             "stack": "stack2",
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D",
#                 "\u5546\u5bb6E"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true,
#                 "\u5546\u5bb6E": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u5806\u53e0\u6570\u636e\uff08\u90e8\u5206\uff09"
#         }
#     ]
# };
#                 chart_0935791836cb40dea6eab33f2b09c27b.setOption(option_0935791836cb40dea6eab33f2b09c27b);
#         });
#     </script>

# %%
def bar_markpoint_type() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-MarkPoint（指定类型）"))
        .set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            markpoint_opts=opts.MarkPointOpts(
                data=[
                    opts.MarkPointItem(type_="max", name="最大值"),
                    opts.MarkPointItem(type_="min", name="最小值"),
#                     opts.MarkPointItem(type_="average", name="平均值"),
                ]
            ),
        )
    )
    return c
c = bar_markpoint_type()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7ea4e7fb3fcf4f60af19d478c1d0e833" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7ea4e7fb3fcf4f60af19d478c1d0e833 = echarts.init(
#                     document.getElementById('7ea4e7fb3fcf4f60af19d478c1d0e833'), 'white', {renderer: 'canvas'});
#                 var option_7ea4e7fb3fcf4f60af19d478c1d0e833 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 74,
#                 49,
#                 134,
#                 146,
#                 104,
#                 55,
#                 80
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 27,
#                 47,
#                 99,
#                 112,
#                 110,
#                 99,
#                 118
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-MarkPoint\uff08\u6307\u5b9a\u7c7b\u578b\uff09"
#         }
#     ]
# };
#                 chart_7ea4e7fb3fcf4f60af19d478c1d0e833.setOption(option_7ea4e7fb3fcf4f60af19d478c1d0e833);
#         });
#     </script>

# %%
def bar_markline_type() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-MarkLine（指定类型）"))
        .set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            markline_opts=opts.MarkLineOpts(
                data=[
                    opts.MarkLineItem(type_="min", name="最小值"),
                    opts.MarkLineItem(type_="max", name="最大值"),
                    opts.MarkLineItem(type_="average", name="平均值"),
                ]
            ),
        )
    )
    return c

c = bar_markline_type()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a18937cebb334314a1ef928a7259935e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a18937cebb334314a1ef928a7259935e = echarts.init(
#                     document.getElementById('a18937cebb334314a1ef928a7259935e'), 'white', {renderer: 'canvas'});
#                 var option_a18937cebb334314a1ef928a7259935e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 96,
#                 63,
#                 88,
#                 71,
#                 91,
#                 129,
#                 100
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 112,
#                 83,
#                 83,
#                 125,
#                 84,
#                 30,
#                 35
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-MarkLine\uff08\u6307\u5b9a\u7c7b\u578b\uff09"
#         }
#     ]
# };
#                 chart_a18937cebb334314a1ef928a7259935e.setOption(option_a18937cebb334314a1ef928a7259935e);
#         });
#     </script>

# %%
def bar_markline_custom() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-MarkLine（自定义）"))
        .set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            markline_opts=opts.MarkLineOpts(
                data=[opts.MarkLineItem(y=50, name="yAxis=50")]
            ),
        )
    )
    return c

c = bar_markline_custom()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d8b0be7aa7d144fd80cdaf7bcd5148a6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d8b0be7aa7d144fd80cdaf7bcd5148a6 = echarts.init(
#                     document.getElementById('d8b0be7aa7d144fd80cdaf7bcd5148a6'), 'white', {renderer: 'canvas'});
#                 var option_d8b0be7aa7d144fd80cdaf7bcd5148a6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 139,
#                 122,
#                 63,
#                 112,
#                 64,
#                 60,
#                 116
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "yAxis=50",
#                         "yAxis": 50
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 120,
#                 142,
#                 48,
#                 141,
#                 134,
#                 91,
#                 32
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "yAxis=50",
#                         "yAxis": 50
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-MarkLine\uff08\u81ea\u5b9a\u4e49\uff09"
#         }
#     ]
# };
#                 chart_d8b0be7aa7d144fd80cdaf7bcd5148a6.setOption(option_d8b0be7aa7d144fd80cdaf7bcd5148a6);
#         });
#     </script>

# %%
def bar_datazoom_slider() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
            datazoom_opts=opts.DataZoomOpts(),
        )
    )
    return c
c = bar_datazoom_slider()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="278fa36e72a84edf9b5c0971c3860eb5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_278fa36e72a84edf9b5c0971c3860eb5 = echarts.init(
#                     document.getElementById('278fa36e72a84edf9b5c0971c3860eb5'), 'white', {renderer: 'canvas'});
#                 var option_278fa36e72a84edf9b5c0971c3860eb5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 27,
#                 20,
#                 23,
#                 28,
#                 29,
#                 7,
#                 21,
#                 21,
#                 21,
#                 15,
#                 7,
#                 30,
#                 9,
#                 19,
#                 28,
#                 7,
#                 17,
#                 17,
#                 2,
#                 6,
#                 11,
#                 9,
#                 15,
#                 20,
#                 30,
#                 12,
#                 11,
#                 30,
#                 7,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u6c34\u5e73\uff09"
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#                 chart_278fa36e72a84edf9b5c0971c3860eb5.setOption(option_278fa36e72a84edf9b5c0971c3860eb5);
#         });
#     </script>

# %%
def bar_datazoom_slider_vertical() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values, color=Faker.rand_color())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-垂直）"),
            datazoom_opts=opts.DataZoomOpts(orient="vertical"),
        )
    )
    return c
c = bar_datazoom_slider_vertical()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="61b5680238c2483cbf788a05a113aff0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_61b5680238c2483cbf788a05a113aff0 = echarts.init(
#                     document.getElementById('61b5680238c2483cbf788a05a113aff0'), 'white', {renderer: 'canvas'});
#                 var option_61b5680238c2483cbf788a05a113aff0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c4ccd3",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 27,
#                 20,
#                 23,
#                 28,
#                 29,
#                 7,
#                 21,
#                 21,
#                 21,
#                 15,
#                 7,
#                 30,
#                 9,
#                 19,
#                 28,
#                 7,
#                 17,
#                 17,
#                 2,
#                 6,
#                 11,
#                 9,
#                 15,
#                 20,
#                 30,
#                 12,
#                 11,
#                 30,
#                 7,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u5782\u76f4\uff09"
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "vertical",
#         "zoomLock": false
#     }
# };
#                 chart_61b5680238c2483cbf788a05a113aff0.setOption(option_61b5680238c2483cbf788a05a113aff0);
#         });
#     </script>

# %%
def bar_datazoom_inside() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values, color=Faker.rand_color())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（inside）"),
            datazoom_opts=opts.DataZoomOpts(type_="inside"),
        )
    )
    return c
c = bar_datazoom_inside()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6eae121fbf5b4912aacea52f21a12806" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6eae121fbf5b4912aacea52f21a12806 = echarts.init(
#                     document.getElementById('6eae121fbf5b4912aacea52f21a12806'), 'white', {renderer: 'canvas'});
#                 var option_6eae121fbf5b4912aacea52f21a12806 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#2f4554",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 27,
#                 20,
#                 23,
#                 28,
#                 29,
#                 7,
#                 21,
#                 21,
#                 21,
#                 15,
#                 7,
#                 30,
#                 9,
#                 19,
#                 28,
#                 7,
#                 17,
#                 17,
#                 2,
#                 6,
#                 11,
#                 9,
#                 15,
#                 20,
#                 30,
#                 12,
#                 11,
#                 30,
#                 7,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08inside\uff09"
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "inside",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#                 chart_6eae121fbf5b4912aacea52f21a12806.setOption(option_6eae121fbf5b4912aacea52f21a12806);
#         });
#     </script>

# %%
def bar_datazoom_both() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values, color=Faker.rand_color())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider+inside）"),
            datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside"), opts.DataZoomOpts(orient="vertical")],
        )
    )
    return c

c = bar_datazoom_both()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6906df65c5e24e6ea05eccf78ead8ad2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6906df65c5e24e6ea05eccf78ead8ad2 = echarts.init(
#                     document.getElementById('6906df65c5e24e6ea05eccf78ead8ad2'), 'white', {renderer: 'canvas'});
#                 var option_6906df65c5e24e6ea05eccf78ead8ad2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#726930",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 27,
#                 20,
#                 23,
#                 28,
#                 29,
#                 7,
#                 21,
#                 21,
#                 21,
#                 15,
#                 7,
#                 30,
#                 9,
#                 19,
#                 28,
#                 7,
#                 17,
#                 17,
#                 2,
#                 6,
#                 11,
#                 9,
#                 15,
#                 20,
#                 30,
#                 12,
#                 11,
#                 30,
#                 7,
#                 3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider+inside\uff09"
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false
#         },
#         {
#             "show": true,
#             "type": "inside",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false
#         },
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "vertical",
#             "zoomLock": false
#         }
#     ]
# };
#                 chart_6906df65c5e24e6ea05eccf78ead8ad2.setOption(option_6906df65c5e24e6ea05eccf78ead8ad2);
#         });
#     </script>

# %%
def bar_histogram() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), category_gap=0, color=Faker.rand_color())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-直方图"))
    )
    return c
c = bar_histogram()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1281dea3ae6d45489f754643c4d6e44c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1281dea3ae6d45489f754643c4d6e44c = echarts.init(
#                     document.getElementById('1281dea3ae6d45489f754643c4d6e44c'), 'white', {renderer: 'canvas'});
#                 var option_1281dea3ae6d45489f754643c4d6e44c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#6950a1",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 93,
#                 148,
#                 133,
#                 131,
#                 125,
#                 66,
#                 55
#             ],
#             "barCategoryGap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u76f4\u65b9\u56fe"
#         }
#     ]
# };
#                 chart_1281dea3ae6d45489f754643c4d6e44c.setOption(option_1281dea3ae6d45489f754643c4d6e44c);
#         });
#     </script>

# %%
def bar_histogram_color() -> Bar:
    x = Faker.dogs + Faker.animal
    xlen = len(x)
    y = []
    for idx, item in enumerate(x):
        if idx <= xlen / 2:
            y.append(
                opts.BarItem(
                    name=item,
                    value=(idx + 1) * 10,
                    itemstyle_opts=opts.ItemStyleOpts(color="#749f83"),
                )
            )
        else:
            y.append(
                opts.BarItem(
                    name=item,
                    value=(xlen + 1 - idx) * 10,
                    itemstyle_opts=opts.ItemStyleOpts(color="#d48265"),
                )
            )

    c = (
        Bar()
        .add_xaxis(x)
        .add_yaxis("series0", y, category_gap=0, color=Faker.rand_color())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-直方图（颜色区分）"))
    )
    return c
c = bar_histogram_color()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f4bc33fd5ed04e1baaa67a10ece9db23" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f4bc33fd5ed04e1baaa67a10ece9db23 = echarts.init(
#                     document.getElementById('f4bc33fd5ed04e1baaa67a10ece9db23'), 'white', {renderer: 'canvas'});
#                 var option_f4bc33fd5ed04e1baaa67a10ece9db23 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#6d8346",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "series0",
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 10,
#                     "itemStyle": {
#                         "color": "#749f83"
#                     }
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 20,
#                     "itemStyle": {
#                         "color": "#749f83"
#                     }
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 30,
#                     "itemStyle": {
#                         "color": "#749f83"
#                     }
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 40,
#                     "itemStyle": {
#                         "color": "#749f83"
#                     }
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 50,
#                     "itemStyle": {
#                         "color": "#749f83"
#                     }
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 60,
#                     "itemStyle": {
#                         "color": "#749f83"
#                     }
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 70,
#                     "itemStyle": {
#                         "color": "#749f83"
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 80,
#                     "itemStyle": {
#                         "color": "#749f83"
#                     }
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 70,
#                     "itemStyle": {
#                         "color": "#d48265"
#                     }
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 60,
#                     "itemStyle": {
#                         "color": "#d48265"
#                     }
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 50,
#                     "itemStyle": {
#                         "color": "#d48265"
#                     }
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 40,
#                     "itemStyle": {
#                         "color": "#d48265"
#                     }
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 30,
#                     "itemStyle": {
#                         "color": "#d48265"
#                     }
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 20,
#                     "itemStyle": {
#                         "color": "#d48265"
#                     }
#                 }
#             ],
#             "barCategoryGap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "series0"
#             ],
#             "selected": {
#                 "series0": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa",
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u76f4\u65b9\u56fe\uff08\u989c\u8272\u533a\u5206\uff09"
#         }
#     ]
# };
#                 chart_f4bc33fd5ed04e1baaa67a10ece9db23.setOption(option_f4bc33fd5ed04e1baaa67a10ece9db23);
#         });
#     </script>

# %%
def bar_rorate_xaxis_label() -> Bar:
    c = (
        Bar()
        .add_xaxis(
            [
                "名字很长的X轴标签1",
                "名字很长的X轴标签2",
                "名字很长的X轴标签3",
                "名字很长的X轴标签4",
                "名字很长的X轴标签5",
                "名字很长的X轴标签6",
            ]
        )
        .add_yaxis("商家A", [10, 20, 30, 40, 50, 40])
        .add_yaxis("商家B", [20, 10, 40, 30, 40, 50])
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
            title_opts=opts.TitleOpts(title="Bar-旋转X轴标签", subtitle="解决标签名字过长的问题"),
        )
    )
    return c

c = bar_rorate_xaxis_label()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3260dc640be148d5a967ea612aad2bea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3260dc640be148d5a967ea612aad2bea = echarts.init(
#                     document.getElementById('3260dc640be148d5a967ea612aad2bea'), 'white', {renderer: 'canvas'});
#                 var option_3260dc640be148d5a967ea612aad2bea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 10,
#                 20,
#                 30,
#                 40,
#                 50,
#                 40
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 20,
#                 10,
#                 40,
#                 30,
#                 40,
#                 50
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e1",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e2",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e3",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e4",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e5",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u65cb\u8f6cX\u8f74\u6807\u7b7e",
#             "subtext": "\u89e3\u51b3\u6807\u7b7e\u540d\u5b57\u8fc7\u957f\u7684\u95ee\u9898"
#         }
#     ]
# };
#                 chart_3260dc640be148d5a967ea612aad2bea.setOption(option_3260dc640be148d5a967ea612aad2bea);
#         });
#     </script>

# %%
def bar_graphic_component() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-Graphic 组件示例"),
            graphic_opts=[
                opts.GraphicGroup(
                    graphic_item=opts.GraphicItem(
                        rotation=JsCode("Math.PI / 4"),
                        bounding="raw",
                        right=110,
                        bottom=110,
                        z=100,
                    ),
                    children=[
                        opts.GraphicRect(
                            graphic_item=opts.GraphicItem(
                                left="center", top="center", z=100
                            ),
                            graphic_shape_opts=opts.GraphicShapeOpts(
                                width=400, height=50
                            ),
                            graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                fill="rgba(0,0,0,0.3)"
                            ),
                        ),
                        opts.GraphicText(
                            graphic_item=opts.GraphicItem(
                                left="center", top="center", z=100
                            ),
                            graphic_textstyle_opts=opts.GraphicTextStyleOpts(
                                text="pyecharts bar chart",
                                font="bold 26px Microsoft YaHei",
                                graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                    fill="#fff"
                                ),
                            ),
                        ),
                    ],
                )
            ],
        )
    )
    return c

c = bar_graphic_component()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="74283a88e90a4c9a978dc3ec4a53c572" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_74283a88e90a4c9a978dc3ec4a53c572 = echarts.init(
#                     document.getElementById('74283a88e90a4c9a978dc3ec4a53c572'), 'white', {renderer: 'canvas'});
#                 var option_74283a88e90a4c9a978dc3ec4a53c572 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 77,
#                 24,
#                 42,
#                 58,
#                 58,
#                 57,
#                 69
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 83,
#                 41,
#                 41,
#                 58,
#                 21,
#                 64,
#                 116
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic \u7ec4\u4ef6\u793a\u4f8b"
#         }
#     ],
#     "graphic": [
#         {
#             "type": "group",
#             "diffChildrenByName": false,
#             "children": [
#                 {
#                     "type": "rect",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "center",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "shape": {
#                         "x": 0,
#                         "y": 0,
#                         "width": 400,
#                         "height": 50
#                     },
#                     "style": {
#                         "fill": "rgba(0,0,0,0.3)",
#                         "line_width": 0
#                     }
#                 },
#                 {
#                     "type": "text",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "center",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "style": {
#                         "text": "pyecharts bar chart",
#                         "x": 0,
#                         "y": 0,
#                         "font": "bold 26px Microsoft YaHei",
#                         "textAlign": "left",
#                         "fill": "#fff",
#                         "line_width": 0
#                     }
#                 }
#             ],
#             "$action": "merge",
#             "rotation": Math.PI / 4,
#             "right": 110,
#             "bottom": 110,
#             "bounding": "raw",
#             "z": 100,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
#             "ignore": false,
#             "cursor": "pointer",
#             "draggable": false,
#             "progressive": false,
#             "width": 0,
#             "height": 0
#         }
#     ]
# };
#                 chart_74283a88e90a4c9a978dc3ec4a53c572.setOption(option_74283a88e90a4c9a978dc3ec4a53c572);
#         });
#     </script>

# %%
def bar_graphic_rect_text_one_component() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-Graphic Rect+Text 1 组件示例"),
            graphic_opts=[
                opts.GraphicGroup(
                    graphic_item=opts.GraphicItem(
                        rotation=JsCode("Math.PI / 4"),
                        bounding="raw",
                        right=110,
                        bottom=110,
                        z=100,
                    ),
                    children=[
                        opts.GraphicRect(
                            graphic_item=opts.GraphicItem(
                                left="center", top="center", z=100
                            ),
                            graphic_shape_opts=opts.GraphicShapeOpts(
                                width=400, height=50
                            ),
                            graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                fill="rgba(0,0,0,0.3)"
                            ),
                        ),
                        opts.GraphicText(
                            graphic_item=opts.GraphicItem(
                                left="center", top="center", z=100
                            ),
                            graphic_textstyle_opts=opts.GraphicTextStyleOpts(
                                text="pyecharts bar chart",
                                font="bold 26px Microsoft YaHei",
                                graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                    fill="#fff"
                                ),
                            ),
                        ),
                    ],
                )
            ],
        )
    )
    return c

c = bar_graphic_rect_text_one_component()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="727949736cff406a9325602f0fbf89b6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_727949736cff406a9325602f0fbf89b6 = echarts.init(
#                     document.getElementById('727949736cff406a9325602f0fbf89b6'), 'white', {renderer: 'canvas'});
#                 var option_727949736cff406a9325602f0fbf89b6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 79,
#                 55,
#                 32,
#                 112,
#                 150,
#                 93,
#                 134
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 54,
#                 127,
#                 74,
#                 116,
#                 60,
#                 31,
#                 116
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic Rect+Text 1 \u7ec4\u4ef6\u793a\u4f8b"
#         }
#     ],
#     "graphic": [
#         {
#             "type": "group",
#             "diffChildrenByName": false,
#             "children": [
#                 {
#                     "type": "rect",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "center",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "shape": {
#                         "x": 0,
#                         "y": 0,
#                         "width": 400,
#                         "height": 50
#                     },
#                     "style": {
#                         "fill": "rgba(0,0,0,0.3)",
#                         "line_width": 0
#                     }
#                 },
#                 {
#                     "type": "text",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "center",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "style": {
#                         "text": "pyecharts bar chart",
#                         "x": 0,
#                         "y": 0,
#                         "font": "bold 26px Microsoft YaHei",
#                         "textAlign": "left",
#                         "fill": "#fff",
#                         "line_width": 0
#                     }
#                 }
#             ],
#             "$action": "merge",
#             "rotation": Math.PI / 4,
#             "right": 110,
#             "bottom": 110,
#             "bounding": "raw",
#             "z": 100,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
#             "ignore": false,
#             "cursor": "pointer",
#             "draggable": false,
#             "progressive": false,
#             "width": 0,
#             "height": 0
#         }
#     ]
# };
#                 chart_727949736cff406a9325602f0fbf89b6.setOption(option_727949736cff406a9325602f0fbf89b6);
#         });
#     </script>

# %%
def bar_graphic_rect_text_two_component() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-Graphic Rect+Text 2 组件示例"),
            graphic_opts=[
                opts.GraphicGroup(
                    graphic_item=opts.GraphicItem(
                        left="50%",
                        top="15%",
                    ),
                    children=[
                        opts.GraphicRect(
                            graphic_item=opts.GraphicItem(
                                z=100,
                                left="center",
                                top="middle",
                            ),
                            graphic_shape_opts=opts.GraphicShapeOpts(
                                width=190, height=90,
                            ),
                            graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                fill="#fff",
                                stroke="#555",
                                line_width=2,
                                shadow_blur=8,
                                shadow_offset_x=3,
                                shadow_offset_y=3,
                                shadow_color="rgba(0,0,0,0.3)",
                            )
                        ),
                        opts.GraphicText(
                            graphic_item=opts.GraphicItem(
                                left="center",
                                top="middle",
                                z=100,
                            ),
                            graphic_textstyle_opts=opts.GraphicTextStyleOpts(
                                text=JsCode(
                                    "['横轴表示数据类别',"
                                    "'纵轴表示数值的值',"
                                    "'这个文本块可以放在图中各',"
                                    "'种位置'].join('\\n')"
                                ),
                                font="14px Microsoft YaHei",
                                graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                    fill="#333"
                                )
                            )
                        )
                    ]
                )
            ],
        )
    )
    return c

c = bar_graphic_rect_text_two_component()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="892c626f2daa478b9f0b44d54e436b15" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_892c626f2daa478b9f0b44d54e436b15 = echarts.init(
#                     document.getElementById('892c626f2daa478b9f0b44d54e436b15'), 'white', {renderer: 'canvas'});
#                 var option_892c626f2daa478b9f0b44d54e436b15 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 112,
#                 128,
#                 54,
#                 26,
#                 90,
#                 116,
#                 115
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 91,
#                 122,
#                 85,
#                 148,
#                 25,
#                 90,
#                 55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic Rect+Text 2 \u7ec4\u4ef6\u793a\u4f8b"
#         }
#     ],
#     "graphic": [
#         {
#             "type": "group",
#             "diffChildrenByName": false,
#             "children": [
#                 {
#                     "type": "rect",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "middle",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "shape": {
#                         "x": 0,
#                         "y": 0,
#                         "width": 190,
#                         "height": 90
#                     },
#                     "style": {
#                         "fill": "#fff",
#                         "stroke": "#555",
#                         "line_width": 2,
#                         "shadowBlur": 8,
#                         "shadowOffsetX": 3,
#                         "shadowOffsetY": 3,
#                         "shadowColor": "rgba(0,0,0,0.3)"
#                     }
#                 },
#                 {
#                     "type": "text",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "middle",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "style": {
#                         "text": ['\u6a2a\u8f74\u8868\u793a\u6570\u636e\u7c7b\u522b','\u7eb5\u8f74\u8868\u793a\u6570\u503c\u7684\u503c','\u8fd9\u4e2a\u6587\u672c\u5757\u53ef\u4ee5\u653e\u5728\u56fe\u4e2d\u5404','\u79cd\u4f4d\u7f6e'].join('\n'),
#                         "x": 0,
#                         "y": 0,
#                         "font": "14px Microsoft YaHei",
#                         "textAlign": "left",
#                         "fill": "#333",
#                         "line_width": 0
#                     }
#                 }
#             ],
#             "$action": "merge",
#             "rotation": 0,
#             "left": "50%",
#             "top": "15%",
#             "bounding": "all",
#             "z": 0,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
#             "ignore": false,
#             "cursor": "pointer",
#             "draggable": false,
#             "progressive": false,
#             "width": 0,
#             "height": 0
#         }
#     ]
# };
#                 chart_892c626f2daa478b9f0b44d54e436b15.setOption(option_892c626f2daa478b9f0b44d54e436b15);
#         });
#     </script>

# %%
def bar_graphic_image_component() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-Graphic Image 组件示例"),
            graphic_opts=[
                opts.GraphicImage(
                    graphic_item=opts.GraphicItem(
                        id_="logo",
                        right=20,
                        top=20,
                        z=-10,
                        bounding="raw",
                        origin=[75, 75],
                    ),
                    graphic_imagestyle_opts=opts.GraphicImageStyleOpts(
                        image="http://echarts.baidu.com/images/favicon.png",
                        width=150,
                        height=150,
                        opacity=0.4,
                    ),
                )
            ],
        )
    )
    return c
c = bar_graphic_image_component()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="27990175893249eebc64b682caf8d997" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_27990175893249eebc64b682caf8d997 = echarts.init(
#                     document.getElementById('27990175893249eebc64b682caf8d997'), 'white', {renderer: 'canvas'});
#                 var option_27990175893249eebc64b682caf8d997 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 45,
#                 100,
#                 124,
#                 48,
#                 121,
#                 41,
#                 24
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 61,
#                 148,
#                 84,
#                 66,
#                 36,
#                 88,
#                 127
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic Image \u7ec4\u4ef6\u793a\u4f8b"
#         }
#     ],
#     "graphic": [
#         {
#             "type": "image",
#             "id": "logo",
#             "$action": "merge",
#             "rotation": 0,
#             "origin": [
#                 75,
#                 75
#             ],
#             "right": 20,
#             "top": 20,
#             "bounding": "raw",
#             "z": -10,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
#             "ignore": false,
#             "cursor": "pointer",
#             "draggable": false,
#             "progressive": false,
#             "width": 0,
#             "height": 0,
#             "style": {
#                 "image": "http://echarts.baidu.com/images/favicon.png",
#                 "x": 0,
#                 "y": 0,
#                 "width": 150,
#                 "height": 150,
#                 "opacity": 0.4
#             }
#         }
#     ]
# };
#                 chart_27990175893249eebc64b682caf8d997.setOption(option_27990175893249eebc64b682caf8d997);
#         });
#     </script>

# %%
from pyecharts.charts import Grid
def bar_graphic_image_with_js_component() -> Grid:
    bar = (
        Bar(init_opts=opts.InitOpts(chart_id="1234"))
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-Graphic Image（旋转功能）组件示例"),
            graphic_opts=[
                opts.GraphicImage(
                    graphic_item=opts.GraphicItem(
                        id_="logo",
                        right=20,
                        top=20,
                        z=-10,
                        bounding="raw",
                        origin=[75, 75],
                    ),
                    graphic_imagestyle_opts=opts.GraphicImageStyleOpts(
                        image="http://echarts.baidu.com/images/favicon.png",
                        width=150,
                        height=150,
                        opacity=0.4,
                    ),
                )
            ],
        )
    )
    c = (
        Grid(
            init_opts=opts.InitOpts(chart_id="1234")
        )
        .add(
            chart=bar,
            grid_opts=opts.GridOpts(
                pos_left="5%",
                pos_right="4%",
                pos_bottom="5%",
            )
        )
        .add_js_funcs("""
            var rotation = 0;
            setInterval(function () {
                chart_1234.setOption({
                    graphic: {
                        id: 'logo',
                        rotation: (rotation += Math.PI / 360) % (Math.PI * 2)
                    }
                });
            }, 30);
        """)
    )
    return c

c = bar_graphic_image_with_js_component()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2dc9b4a740144b01a5c7843fe141df15" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2dc9b4a740144b01a5c7843fe141df15 = echarts.init(
#                     document.getElementById('2dc9b4a740144b01a5c7843fe141df15'), 'white', {renderer: 'canvas'});
#
#             var rotation = 0;
#             setInterval(function () {
#                 chart_1234.setOption({
#                     graphic: {
#                         id: 'logo',
#                         rotation: (rotation += Math.PI / 360) % (Math.PI * 2)
#                     }
#                 });
#             }, 30);
#
#                 var option_2dc9b4a740144b01a5c7843fe141df15 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 131,
#                 22,
#                 99,
#                 137,
#                 108,
#                 76,
#                 146
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 82,
#                 27,
#                 92,
#                 38,
#                 129,
#                 136,
#                 115
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic Image\uff08\u65cb\u8f6c\u529f\u80fd\uff09\u7ec4\u4ef6\u793a\u4f8b"
#         }
#     ],
#     "graphic": [
#         {
#             "type": "image",
#             "id": "logo",
#             "$action": "merge",
#             "rotation": 0,
#             "origin": [
#                 75,
#                 75
#             ],
#             "right": 20,
#             "top": 20,
#             "bounding": "raw",
#             "z": -10,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
#             "ignore": false,
#             "cursor": "pointer",
#             "draggable": false,
#             "progressive": false,
#             "width": 0,
#             "height": 0,
#             "style": {
#                 "image": "http://echarts.baidu.com/images/favicon.png",
#                 "x": 0,
#                 "y": 0,
#                 "width": 150,
#                 "height": 150,
#                 "opacity": 0.4
#             }
#         }
#     ],
#     "grid": [
#         {
#             "left": "5%",
#             "right": "4%",
#             "bottom": "5%"
#         }
#     ]
# };
#                 chart_2dc9b4a740144b01a5c7843fe141df15.setOption(option_2dc9b4a740144b01a5c7843fe141df15);
#         });
#     </script>

# %%
def bar_with_brush() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-Brush 示例", subtitle="我是副标题"),
            brush_opts=opts.BrushOpts(),
        )
    )
    return c
c = bar_with_brush()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e767cf704cfc400fa183de2f7b22f031" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e767cf704cfc400fa183de2f7b22f031 = echarts.init(
#                     document.getElementById('e767cf704cfc400fa183de2f7b22f031'), 'white', {renderer: 'canvas'});
#                 var option_e767cf704cfc400fa183de2f7b22f031 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 100,
#                 44,
#                 84,
#                 39,
#                 92,
#                 35,
#                 112
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 26,
#                 125,
#                 109,
#                 25,
#                 72,
#                 86,
#                 120
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Brush \u793a\u4f8b",
#             "subtext": "\u6211\u662f\u526f\u6807\u9898"
#         }
#     ],
#     "brush": {
#         "toolbox": [
#             "rect",
#             "polygon",
#             "keep",
#             "clear"
#         ],
#         "brushType": "rect",
#         "brushMode": "single",
#         "transformable": true,
#         "brushStyle": {
#             "borderWidth": 1,
#             "color": "rgba(120,140,180,0.3)",
#             "borderColor": "rgba(120,140,180,0.8)"
#         },
#         "throttleType": "fixRate",
#         "throttleDelay": 0,
#         "removeOnClick": true
#     }
# };
#                 chart_e767cf704cfc400fa183de2f7b22f031.setOption(option_e767cf704cfc400fa183de2f7b22f031);
#         });
#     </script>

# %%
def bar_custom_bar_color() -> Bar:
    color_function = """
        function (params) {
            if (params.value > 0 && params.value < 50) {
                return 'red';
            } else if (params.value > 50 && params.value < 100) {
                return 'blue';
            }
            return 'green';
        }
        """
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis(
            "商家A",
            Faker.values(),
            itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_function)),
        )
        .add_yaxis(
            "商家B",
            Faker.values(),
            itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_function)),
        )
        .add_yaxis(
            "商家C",
            Faker.values(),
            itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_function)),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-自定义柱状颜色"))
    )
    return c
c = bar_custom_bar_color()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b001e102f40346abab1f548cae061836" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b001e102f40346abab1f548cae061836 = echarts.init(
#                     document.getElementById('b001e102f40346abab1f548cae061836'), 'white', {renderer: 'canvas'});
#                 var option_b001e102f40346abab1f548cae061836 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 81,
#                 117,
#                 131,
#                 74,
#                 106,
#                 24,
#                 88
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color":         function (params) {            if (params.value > 0 && params.value < 50) {                return 'red';            } else if (params.value > 50 && params.value < 100) {                return 'blue';            }            return 'green';        }
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 29,
#                 67,
#                 96,
#                 21,
#                 71,
#                 79,
#                 103
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color":         function (params) {            if (params.value > 0 && params.value < 50) {                return 'red';            } else if (params.value > 50 && params.value < 100) {                return 'blue';            }            return 'green';        }
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 76,
#                 102,
#                 116,
#                 96,
#                 48,
#                 69,
#                 72
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color":         function (params) {            if (params.value > 0 && params.value < 50) {                return 'red';            } else if (params.value > 50 && params.value < 100) {                return 'blue';            }            return 'green';        }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u81ea\u5b9a\u4e49\u67f1\u72b6\u989c\u8272"
#         }
#     ]
# };
#                 chart_b001e102f40346abab1f548cae061836.setOption(option_b001e102f40346abab1f548cae061836);
#         });
#     </script>

# %% [markdown]
# # Boxplot：箱形图

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot


def boxpolt_base() -> Boxplot:
    v1 = [
        [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880]
        + [1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
        [960, 940, 960, 940, 880, 800, 850, 880, 900]
        + [840, 830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
    ]
    v2 = [
        [890, 810, 810, 820, 800, 770, 760, 740, 750, 760]
        + [910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
        [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870]
        + [870, 810, 740, 810, 940, 950, 800, 810, 870],
    ]
    c = Boxplot()
    c.add_xaxis(["expr1", "expr2"]).add_yaxis("A", c.prepare_data(v1)).add_yaxis(
        "B", c.prepare_data(v2)
    ).set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
    return c
c = boxpolt_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a3cf9f4808d741a6b2fa2dc6a4303345" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a3cf9f4808d741a6b2fa2dc6a4303345 = echarts.init(
#                     document.getElementById('a3cf9f4808d741a6b2fa2dc6a4303345'), 'white', {renderer: 'canvas'});
#                 var option_a3cf9f4808d741a6b2fa2dc6a4303345 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_a3cf9f4808d741a6b2fa2dc6a4303345.setOption(option_a3cf9f4808d741a6b2fa2dc6a4303345);
#         });
#     </script>

# %%
def boxpolt_base() -> Boxplot:
    v1 = [
        [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880],
        [960, 940, 960, 940, 880, 800, 850, 880, 900]
    ]
    v2 = [
        [890, 810, 810, 820, 800, 770, 760, 740, 750, 760],
        [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870]
    ]
    c = Boxplot()
    c.add_xaxis(["expr1", "expr2"]).add_yaxis("A", c.prepare_data(v1)).add_yaxis(
        "B", c.prepare_data(v2)
    ).set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
    return c
c = boxpolt_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="976603466b4e4df3b5b1f081c8f601e3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_976603466b4e4df3b5b1f081c8f601e3 = echarts.init(
#                     document.getElementById('976603466b4e4df3b5b1f081c8f601e3'), 'white', {renderer: 'canvas'});
#                 var option_976603466b4e4df3b5b1f081c8f601e3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     740,
#                     850.0,
#                     915.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     800,
#                     865.0,
#                     900,
#                     950.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     740,
#                     757.5,
#                     785.0,
#                     812.5,
#                     890
#                 ],
#                 [
#                     760,
#                     790,
#                     810,
#                     850,
#                     890
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_976603466b4e4df3b5b1f081c8f601e3.setOption(option_976603466b4e4df3b5b1f081c8f601e3);
#         });
#     </script>

# %% [markdown]
# # EffectScatter：涟漪特效散点图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import EffectScatter
from pyecharts.globals import SymbolType


def effectscatter_base() -> EffectScatter:
    c = (
        EffectScatter()
        .add_xaxis(Faker.choose())
        .add_yaxis("", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="EffectScatter-基本示例"))
    )
    return c
c = effectscatter_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="66a1f034477943be8c2a920fbd90b830" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_66a1f034477943be8c2a920fbd90b830 = echarts.init(
#                     document.getElementById('66a1f034477943be8c2a920fbd90b830'), 'white', {renderer: 'canvas'});
#                 var option_66a1f034477943be8c2a920fbd90b830 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     125
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     112
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     38
#                 ],
#                 [
#                     "\u5468\u56db",
#                     46
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     113
#                 ],
#                 [
#                     "\u5468\u516d",
#                     131
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     131
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "EffectScatter-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_66a1f034477943be8c2a920fbd90b830.setOption(option_66a1f034477943be8c2a920fbd90b830);
#         });
#     </script>

# %%
def effectscatter_splitline() -> EffectScatter:
    c = (
        EffectScatter()
        .add_xaxis(Faker.choose())
        .add_yaxis("", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="EffectScatter-显示分割线"),
            xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
            yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
        )
    )
    return c
c = effectscatter_splitline()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="975996a03c3d4cc3be381e6ea5696409" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_975996a03c3d4cc3be381e6ea5696409 = echarts.init(
#                     document.getElementById('975996a03c3d4cc3be381e6ea5696409'), 'white', {renderer: 'canvas'});
#                 var option_975996a03c3d4cc3be381e6ea5696409 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     95
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     32
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     34
#                 ],
#                 [
#                     "\u7eff\u8336",
#                     31
#                 ],
#                 [
#                     "\u5976\u8336",
#                     62
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     133
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     144
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "EffectScatter-\u663e\u793a\u5206\u5272\u7ebf"
#         }
#     ]
# };
#                 chart_975996a03c3d4cc3be381e6ea5696409.setOption(option_975996a03c3d4cc3be381e6ea5696409);
#         });
#     </script>

# %%
def effectscatter_symbol() -> EffectScatter:
    c = (
        EffectScatter()
        .add_xaxis(Faker.choose())
        .add_yaxis("", Faker.values(), symbol=SymbolType.ARROW)
    ).set_global_opts(title_opts=opts.TitleOpts(title="EffectScatter-不同Symbol"))
    return c
c = effectscatter_symbol()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7588f7b1b9fe49f39be7e6279ebd54e6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7588f7b1b9fe49f39be7e6279ebd54e6 = echarts.init(
#                     document.getElementById('7588f7b1b9fe49f39be7e6279ebd54e6'), 'white', {renderer: 'canvas'});
#                 var option_7588f7b1b9fe49f39be7e6279ebd54e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "arrow",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     65
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     26
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     111
#                 ],
#                 [
#                     "\u5468\u56db",
#                     59
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     81
#                 ],
#                 [
#                     "\u5468\u516d",
#                     25
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     43
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "EffectScatter-\u4e0d\u540cSymbol"
#         }
#     ]
# };
#                 chart_7588f7b1b9fe49f39be7e6279ebd54e6.setOption(option_7588f7b1b9fe49f39be7e6279ebd54e6);
#         });
#     </script>

# %% [markdown]
# # HeatMap：热力图

# %%
import random

from pyecharts.faker import  Faker
from pyecharts import options as opts
from pyecharts.charts import HeatMap


def heatmap_base() -> HeatMap:
    value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
    c = (
        HeatMap()
        .add_xaxis(Faker.clock)
        .add_yaxis("series0", Faker.week, value)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="HeatMap-基本示例"),
            visualmap_opts=opts.VisualMapOpts(),
        )
    )
    return c
c = heatmap_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bbf7c0cadc384366b2455ac19a44376f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bbf7c0cadc384366b2455ac19a44376f = echarts.init(
#                     document.getElementById('bbf7c0cadc384366b2455ac19a44376f'), 'white', {renderer: 'canvas'});
#                 var option_bbf7c0cadc384366b2455ac19a44376f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "series0",
#             "data": [
#                 [
#                     0,
#                     0,
#                     47
#                 ],
#                 [
#                     0,
#                     1,
#                     19
#                 ],
#                 [
#                     0,
#                     2,
#                     33
#                 ],
#                 [
#                     0,
#                     3,
#                     19
#                 ],
#                 [
#                     0,
#                     4,
#                     19
#                 ],
#                 [
#                     0,
#                     5,
#                     6
#                 ],
#                 [
#                     0,
#                     6,
#                     25
#                 ],
#                 [
#                     1,
#                     0,
#                     36
#                 ],
#                 [
#                     1,
#                     1,
#                     7
#                 ],
#                 [
#                     1,
#                     2,
#                     21
#                 ],
#                 [
#                     1,
#                     3,
#                     1
#                 ],
#                 [
#                     1,
#                     4,
#                     9
#                 ],
#                 [
#                     1,
#                     5,
#                     39
#                 ],
#                 [
#                     1,
#                     6,
#                     16
#                 ],
#                 [
#                     2,
#                     0,
#                     11
#                 ],
#                 [
#                     2,
#                     1,
#                     12
#                 ],
#                 [
#                     2,
#                     2,
#                     39
#                 ],
#                 [
#                     2,
#                     3,
#                     33
#                 ],
#                 [
#                     2,
#                     4,
#                     1
#                 ],
#                 [
#                     2,
#                     5,
#                     16
#                 ],
#                 [
#                     2,
#                     6,
#                     48
#                 ],
#                 [
#                     3,
#                     0,
#                     18
#                 ],
#                 [
#                     3,
#                     1,
#                     41
#                 ],
#                 [
#                     3,
#                     2,
#                     3
#                 ],
#                 [
#                     3,
#                     3,
#                     47
#                 ],
#                 [
#                     3,
#                     4,
#                     44
#                 ],
#                 [
#                     3,
#                     5,
#                     25
#                 ],
#                 [
#                     3,
#                     6,
#                     37
#                 ],
#                 [
#                     4,
#                     0,
#                     18
#                 ],
#                 [
#                     4,
#                     1,
#                     39
#                 ],
#                 [
#                     4,
#                     2,
#                     49
#                 ],
#                 [
#                     4,
#                     3,
#                     42
#                 ],
#                 [
#                     4,
#                     4,
#                     33
#                 ],
#                 [
#                     4,
#                     5,
#                     10
#                 ],
#                 [
#                     4,
#                     6,
#                     49
#                 ],
#                 [
#                     5,
#                     0,
#                     33
#                 ],
#                 [
#                     5,
#                     1,
#                     31
#                 ],
#                 [
#                     5,
#                     2,
#                     35
#                 ],
#                 [
#                     5,
#                     3,
#                     42
#                 ],
#                 [
#                     5,
#                     4,
#                     25
#                 ],
#                 [
#                     5,
#                     5,
#                     20
#                 ],
#                 [
#                     5,
#                     6,
#                     24
#                 ],
#                 [
#                     6,
#                     0,
#                     17
#                 ],
#                 [
#                     6,
#                     1,
#                     23
#                 ],
#                 [
#                     6,
#                     2,
#                     40
#                 ],
#                 [
#                     6,
#                     3,
#                     40
#                 ],
#                 [
#                     6,
#                     4,
#                     3
#                 ],
#                 [
#                     6,
#                     5,
#                     23
#                 ],
#                 [
#                     6,
#                     6,
#                     37
#                 ],
#                 [
#                     7,
#                     0,
#                     29
#                 ],
#                 [
#                     7,
#                     1,
#                     45
#                 ],
#                 [
#                     7,
#                     2,
#                     44
#                 ],
#                 [
#                     7,
#                     3,
#                     0
#                 ],
#                 [
#                     7,
#                     4,
#                     31
#                 ],
#                 [
#                     7,
#                     5,
#                     32
#                 ],
#                 [
#                     7,
#                     6,
#                     42
#                 ],
#                 [
#                     8,
#                     0,
#                     16
#                 ],
#                 [
#                     8,
#                     1,
#                     23
#                 ],
#                 [
#                     8,
#                     2,
#                     7
#                 ],
#                 [
#                     8,
#                     3,
#                     44
#                 ],
#                 [
#                     8,
#                     4,
#                     37
#                 ],
#                 [
#                     8,
#                     5,
#                     32
#                 ],
#                 [
#                     8,
