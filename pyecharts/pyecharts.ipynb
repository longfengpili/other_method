# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK
from pyecharts.charts import *
from pyecharts import options as opts

# %% [markdown]
# # 五分钟上手

# %% [markdown]
# ## 基础

# %%
bar = Bar()
bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
# render 会生成本地 HTML 文件，默认会在当前目录生成 render.html 文件
# 也可以传入路径参数，如 bar.render("mycharts.html")
# bar.render()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bfaa8ca494104a06900441e5767d3fda" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bfaa8ca494104a06900441e5767d3fda = echarts.init(
#                     document.getElementById('bfaa8ca494104a06900441e5767d3fda'), 'white', {renderer: 'canvas'});
#                 var option_bfaa8ca494104a06900441e5767d3fda = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_bfaa8ca494104a06900441e5767d3fda.setOption(option_bfaa8ca494104a06900441e5767d3fda);
#         });
#     </script>

# %%
bar = (
    Bar()
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9a42ac50a2a24788a0846995d954edf5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9a42ac50a2a24788a0846995d954edf5 = echarts.init(
#                     document.getElementById('9a42ac50a2a24788a0846995d954edf5'), 'white', {renderer: 'canvas'});
#                 var option_9a42ac50a2a24788a0846995d954edf5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_9a42ac50a2a24788a0846995d954edf5.setOption(option_9a42ac50a2a24788a0846995d954edf5);
#         });
#     </script>

# %%
bar = (
    Bar()
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
#     .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
    # 或者直接使用字典参数
    .set_global_opts(title_opts={"text": "主标题", "subtext": "副标题"})
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="36c6d8e249054ee5b48b5a7d559a2d00" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_36c6d8e249054ee5b48b5a7d559a2d00 = echarts.init(
#                     document.getElementById('36c6d8e249054ee5b48b5a7d559a2d00'), 'white', {renderer: 'canvas'});
#                 var option_36c6d8e249054ee5b48b5a7d559a2d00 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": {
#         "text": "\u4e3b\u6807\u9898",
#         "subtext": "\u526f\u6807\u9898"
#     }
# };
#                 chart_36c6d8e249054ee5b48b5a7d559a2d00.setOption(option_36c6d8e249054ee5b48b5a7d559a2d00);
#         });
#     </script>

# %%
# 不习惯链式调用的开发者依旧可以单独调用方法
bar = Bar()
bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
bar.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="18aef9e0619a4430a4d7dae2cb4cdfd7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_18aef9e0619a4430a4d7dae2cb4cdfd7 = echarts.init(
#                     document.getElementById('18aef9e0619a4430a4d7dae2cb4cdfd7'), 'white', {renderer: 'canvas'});
#                 var option_18aef9e0619a4430a4d7dae2cb4cdfd7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#                 chart_18aef9e0619a4430a4d7dae2cb4cdfd7.setOption(option_18aef9e0619a4430a4d7dae2cb4cdfd7);
#         });
#     </script>

# %% [markdown]
# ## 进阶话题-渲染图片

# %%
from pyecharts.render import make_snapshot

# 使用 snapshot-selenium 渲染图片
from snapshot_selenium import snapshot

bar = (
    Bar()
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
)
# make_snapshot(snapshot, bar.render(), "bar.png")

# %% [markdown]
# ## 使用主题

# %%
# 内置主题类型可查看 pyecharts.globals.ThemeType
from pyecharts.globals import ThemeType

bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    .add_yaxis("商家B", [15, 6, 45, 20, 35, 66])
    .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="61fa12fdc182407d80af122238759209" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_61fa12fdc182407d80af122238759209 = echarts.init(
#                     document.getElementById('61fa12fdc182407d80af122238759209'), 'light', {renderer: 'canvas'});
#                 var option_61fa12fdc182407d80af122238759209 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 15,
#                 6,
#                 45,
#                 20,
#                 35,
#                 66
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#                 chart_61fa12fdc182407d80af122238759209.setOption(option_61fa12fdc182407d80af122238759209);
#         });
#     </script>

# %% [markdown]
# # 基本图表

# %% [markdown]
# ## 日历表

# %%
import datetime
import random

from pyecharts import options as opts
from pyecharts.charts import Calendar

# %%
def calendar_base() -> Calendar:
    begin = datetime.date(2017, 1, 1)
    end = datetime.date(2017, 7, 31)
    data = [
        [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
        for i in range((end - begin).days + 1)
    ]

    c = (
        Calendar()
        .add("步数", data, calendar_opts=opts.CalendarOpts(range_="2017"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
            visualmap_opts=opts.VisualMapOpts(
                max_=30000,
                min_=0,
                orient="horizontal",
#                 is_piecewise=True,
                pos_top="230px",
                pos_left="100px",
            ) #图例格式,
        )
    )
    return c

# %%
c = calendar_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="77bd6d60595d4cd38662fcf894c011ad" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_77bd6d60595d4cd38662fcf894c011ad = echarts.init(
#                     document.getElementById('77bd6d60595d4cd38662fcf894c011ad'), 'white', {renderer: 'canvas'});
#                 var option_77bd6d60595d4cd38662fcf894c011ad = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "\u6b65\u6570",
#             "data": [
#                 [
#                     "2017-01-01",
#                     16646
#                 ],
#                 [
#                     "2017-01-02",
#                     11071
#                 ],
#                 [
#                     "2017-01-03",
#                     13230
#                 ],
#                 [
#                     "2017-01-04",
#                     15441
#                 ],
#                 [
#                     "2017-01-05",
#                     19201
#                 ],
#                 [
#                     "2017-01-06",
#                     20473
#                 ],
#                 [
#                     "2017-01-07",
#                     7749
#                 ],
#                 [
#                     "2017-01-08",
#                     12746
#                 ],
#                 [
#                     "2017-01-09",
#                     17411
#                 ],
#                 [
#                     "2017-01-10",
#                     18940
#                 ],
#                 [
#                     "2017-01-11",
#                     17049
#                 ],
#                 [
#                     "2017-01-12",
#                     6913
#                 ],
#                 [
#                     "2017-01-13",
#                     3218
#                 ],
#                 [
#                     "2017-01-14",
#                     19669
#                 ],
#                 [
#                     "2017-01-15",
#                     3828
#                 ],
#                 [
#                     "2017-01-16",
#                     2800
#                 ],
#                 [
#                     "2017-01-17",
#                     9086
#                 ],
#                 [
#                     "2017-01-18",
#                     9505
#                 ],
#                 [
#                     "2017-01-19",
#                     17146
#                 ],
#                 [
#                     "2017-01-20",
#                     7536
#                 ],
#                 [
#                     "2017-01-21",
#                     10867
#                 ],
#                 [
#                     "2017-01-22",
#                     14450
#                 ],
#                 [
#                     "2017-01-23",
#                     11226
#                 ],
#                 [
#                     "2017-01-24",
#                     20553
#                 ],
#                 [
#                     "2017-01-25",
#                     11620
#                 ],
#                 [
#                     "2017-01-26",
#                     23696
#                 ],
#                 [
#                     "2017-01-27",
#                     4243
#                 ],
#                 [
#                     "2017-01-28",
#                     19366
#                 ],
#                 [
#                     "2017-01-29",
#                     14369
#                 ],
#                 [
#                     "2017-01-30",
#                     7841
#                 ],
#                 [
#                     "2017-01-31",
#                     20399
#                 ],
#                 [
#                     "2017-02-01",
#                     20844
#                 ],
#                 [
#                     "2017-02-02",
#                     23851
#                 ],
#                 [
#                     "2017-02-03",
#                     7491
#                 ],
#                 [
#                     "2017-02-04",
#                     8624
#                 ],
#                 [
#                     "2017-02-05",
#                     11362
#                 ],
#                 [
#                     "2017-02-06",
#                     10722
#                 ],
#                 [
#                     "2017-02-07",
#                     23260
#                 ],
#                 [
#                     "2017-02-08",
#                     1790
#                 ],
#                 [
#                     "2017-02-09",
#                     22957
#                 ],
#                 [
#                     "2017-02-10",
#                     7676
#                 ],
#                 [
#                     "2017-02-11",
#                     7611
#                 ],
#                 [
#                     "2017-02-12",
#                     14855
#                 ],
#                 [
#                     "2017-02-13",
#                     1583
#                 ],
#                 [
#                     "2017-02-14",
#                     14773
#                 ],
#                 [
#                     "2017-02-15",
#                     1141
#                 ],
#                 [
#                     "2017-02-16",
#                     5911
#                 ],
#                 [
#                     "2017-02-17",
#                     3790
#                 ],
#                 [
#                     "2017-02-18",
#                     3323
#                 ],
#                 [
#                     "2017-02-19",
#                     5662
#                 ],
#                 [
#                     "2017-02-20",
#                     14921
#                 ],
#                 [
#                     "2017-02-21",
#                     8265
#                 ],
#                 [
#                     "2017-02-22",
#                     2094
#                 ],
#                 [
#                     "2017-02-23",
#                     16497
#                 ],
#                 [
#                     "2017-02-24",
#                     18653
#                 ],
#                 [
#                     "2017-02-25",
#                     15451
#                 ],
#                 [
#                     "2017-02-26",
#                     15523
#                 ],
#                 [
#                     "2017-02-27",
#                     8438
#                 ],
#                 [
#                     "2017-02-28",
#                     17471
#                 ],
#                 [
#                     "2017-03-01",
#                     2071
#                 ],
#                 [
#                     "2017-03-02",
#                     13536
#                 ],
#                 [
#                     "2017-03-03",
#                     6325
#                 ],
#                 [
#                     "2017-03-04",
#                     18860
#                 ],
#                 [
#                     "2017-03-05",
#                     22254
#                 ],
#                 [
#                     "2017-03-06",
#                     6432
#                 ],
#                 [
#                     "2017-03-07",
#                     9374
#                 ],
#                 [
#                     "2017-03-08",
#                     23955
#                 ],
#                 [
#                     "2017-03-09",
#                     13122

# %% [markdown]
# ## funnel

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page


def funnel_base() -> Funnel:
    c = (
        Funnel()
        .add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())],
            sort_="ascending",
            label_opts=opts.LabelOpts(position="inside"))
        .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
    )
    return c
[list(z) for z in zip(Faker.choose(), Faker.values())]
c = funnel_base()
c.render_notebook()
# Out:
# [['河马', 128],
#  ['蟒蛇', 117],
#  ['老虎', 98],
#  ['大象', 128],
#  ['兔子', 95],
#  ['熊猫', 114],
#  ['狮子', 131]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="72c514539c3644a5aec37075f1d9f8a7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_72c514539c3644a5aec37075f1d9f8a7 = echarts.init(
#                     document.getElementById('72c514539c3644a5aec37075f1d9f8a7'), 'white', {renderer: 'canvas'});
#                 var option_72c514539c3644a5aec37075f1d9f8a7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 63
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 105
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u897f\u74dc",
#                 "\u96ea\u68a8",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {
#                 "\u8349\u8393": true,
#                 "\u8292\u679c": true,
#                 "\u8461\u8404": true,
#                 "\u96ea\u68a8": true,
#                 "\u897f\u74dc": true,
#                 "\u67e0\u6aac": true,
#                 "\u8f66\u5398\u5b50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_72c514539c3644a5aec37075f1d9f8a7.setOption(option_72c514539c3644a5aec37075f1d9f8a7);
#         });
#     </script>

# %% [markdown]
# ## 仪表图

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page


def gauge_base() -> Gauge:
    c = (
        Gauge()
        .add("", [("完", 20),("完成", 60),("完成率", 80)],
#             is_selected=True,
             axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#67e0e3"), (0.7, "#37a2da"), (1, "#fd666d")], width=30)),
#              label_opts=opts.LabelOpts(formatter="{value}"),
            )
        .set_global_opts(title_opts=opts.TitleOpts(title="Gauge-分割段数-Label"),
#             legend_opts=opts.LegendOpts(is_show=True),
                        )
    )
    return c

c = gauge_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6e013c4accfc4c8c9b14dde85e338012" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6e013c4accfc4c8c9b14dde85e338012 = echarts.init(
#                     document.getElementById('6e013c4accfc4c8c9b14dde85e338012'), 'white', {renderer: 'canvas'});
#                 var option_6e013c4accfc4c8c9b14dde85e338012 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u5b8c\u6210",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 80
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u5206\u5272\u6bb5\u6570-Label"
#         }
#     ]
# };
#                 chart_6e013c4accfc4c8c9b14dde85e338012.setOption(option_6e013c4accfc4c8c9b14dde85e338012);
#         });
#     </script>
